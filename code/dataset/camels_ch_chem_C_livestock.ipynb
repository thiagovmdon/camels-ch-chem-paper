# %% [markdown]
# # Livestock dataset extraction
#
# Author: Thiago Nascimento (thiago.nascimento@eawag.ch)
#
# This notebook is used to retrieve and concatenate the livestock dataset into a table for publication alongisde the used data.
#
# ## Requirements
# **Python:**
#
# * Python>=3.6
# * Jupyter
# * geopandas=0.10.2
# * numpy
# * os
# * pandas=2.1.3
# * tqdm
#
# Check the Github repository for an environment.yml (for conda environments) or requirements.txt (pip) file.
#
# **Files:**
#
# * GVE_Catchments.shp
#
#
# **Directory:**
#
# * Clone the GitHub directory locally
# * Place any third-data variables in their respective directory.
# * ONLY update the "PATH" variable in the section "Configurations", with their relative path to the EStreams directory.
#
#
# ## References
# *
# ## Observations
# * Part of the data is interpolated.

# %% [markdown]
# # Import modules

# %%
import pandas as pd
import numpy as np
import tqdm as tqdm
import os
import warnings
import geopandas as gpd

# %% [markdown]
# # Configurations

# %%
# Only editable variables:
# Relative path to your local directory
PATH = "../.."
# Suppress all warnings
warnings.filterwarnings("ignore")

path_data = r"C:\Users\nascimth\Documents\data\CAMELS_CH_Chem\data"

# %% [markdown]
# * #### The users should NOT change anything in the code below here.

# %%
# Non-editable variables:
PATH_OUTPUT = "results\Dataset\catchment_aggregated_data\livestock_data"

# Set the directory:
os.chdir(PATH)

# %% [markdown]
# # Import data

# %%
catchments_gve = gpd.read_file(path_data+'\shapefile_gve\GVE_Catchments.shp')
catchments_gve["bafu_id"] = catchments_gve["gauge_id"]
catchments_gve
# Out:
#      naduf_id     naduf_name   water_body     Shape_Leng       ID  gauge_id  \
# 0        1837  Porte_du_Scex        Rhône  581764.280706  nd_1837       0.0
# 1        1833          Brugg         Aare  827826.334191  nd_1833       0.0
# 2        1835      Mellingen        Reuss  423443.101185  nd_1835       0.0
# 3        1823    Andelfingen         Thur  278840.437214  nd_1823       0.0
# 4        1842        Martina          Inn  293426.137861  nd_1842       0.0
# ..        ...            ...          ...            ...      ...       ...
# 182         0           None        Simme  151671.931781  nw_1919       0.0
# 183         0           None        Sorne   82837.276182  nw_1504       0.0
# 184         0           None         Aare  745868.466423  nw_1142       0.0
# 185         0           None       Drance  138710.844326  nw_3860       0.0
# 186         0           None  Kleine_Emme  142184.941396  nw_1181       0.0
#
#     gauge_name  nawa_id     nawa_name     Shape_Le_1  ...  gve_2015_h  \
# 0         None      0.0          None  581812.194190  ...    0.071078
# 1         None      0.0          None  827842.590414  ...    0.494300
# 2         None      0.0          None  423447.043212  ...    0.429804
# 3         None      0.0          None  278852.096268  ...    0.878186
# 4         None      0.0          None  293431.436471  ...    0.058669
# ..         ...      ...           ...            ...  ...         ...
# 182       None   1919.0    Latterbach  151676.136857  ...    0.259554
# 183       None   1504.0      Delémont   82838.882339  ...    0.441431
# 184       None   1142.0         Nidau  745881.109854  ...    0.385930
# 185       None   3860.0      Martigny  138730.554523  ...    0.073408
# 186       None   1181.0  Emmen-Littau  142185.158427  ...    0.708337
#
#      gve_2016_h  gve_2017_h  gve_2018_h  gve_2019_h  gve_2020_h  gve_2021_h  \
# 0      0.070785    0.072441    0.072648    0.071371    0.071871    0.071714
# 1      0.490025    0.487356    0.486703    0.480337    0.477349    0.479700
# 2      0.430639    0.427754    0.429399    0.425385    0.422040    0.424314
# 3      0.875332    0.873078    0.873069    0.858348    0.855597    0.869395
# 4      0.057852    0.058343    0.058582    0.057470    0.055563    0.055084
# ..          ...         ...         ...         ...         ...         ...
# 182    0.261628    0.261090    0.259942    0.255896    0.251801    0.254637
# 183    0.444679    0.441823    0.438026    0.431327    0.426675    0.424547
# 184    0.381925    0.379199    0.378388    0.374406    0.371942    0.373288
# 185    0.073306    0.073382    0.074332    0.072997    0.072378    0.072555
# 186    0.711608    0.711630    0.725594    0.715432    0.712891    0.716207
#
#      gve_2022_h                                           geometry  bafu_id
# 0      0.071609  POLYGON Z ((2674253.038 1167429.881 0.000, 267...      0.0
# 1      0.484112  POLYGON Z ((2655969.680 1259695.589 0.000, 265...      0.0
# 2      0.422356  POLYGON Z ((2663723.380 1252919.068 0.000, 266...      0.0
# 3      0.868562  POLYGON Z ((2719445.088 1279260.056 0.000, 271...      0.0
# 4      0.055510  POLYGON Z ((2818919.419 1201129.962 0.000, 281...      0.0
# ..          ...                                                ...      ...
# 182    0.256755  POLYGON Z ((2605018.868 1172839.620 0.000, 260...      0.0
# 183    0.431703  POLYGON Z ((2584725.396 1248420.902 0.000, 258...      0.0
# 184    0.379099  POLYGON Z ((2597091.802 1231250.148 0.000, 259...      0.0
# 185    0.073715  POLYGON Z ((2583409.306 1108018.362 0.000, 258...      0.0
# 186    0.717919  POLYGON Z ((2653429.237 1216261.807 0.000, 265...      0.0
#
# [187 rows x 75 columns]

# %%
# Network CAMELS_CH_Chem
network_camels_ch_chem = pd.read_excel(path_data+"\CAMELS_CH_chem_stations_short_v3.xlsx", sheet_name='all_5')
#network_camels_ch_chem.set_index("basin_id", inplace=True)
network_camels_ch_chem
# Out:
#      basin_id  bafu_id  naduf_id  nawa_id isot_id            hydro_station  \
# 0        2009   2009.0    1837.0   1837.0   NIO04            Porte du Scex
# 1        2011   2011.0       NaN   4070.0     NaN                     Sion
# 2        2016   2016.0    1833.0   1833.0   NIO02                    Brugg
# 3        2018   2018.0    1835.0   1339.0     NaN                Mellingen
# 4        2019   2019.0       NaN   1852.0   NIO01              Brienzwiler
# ..        ...      ...       ...      ...     ...                      ...
# 110      2617   2617.0       NaN      NaN     NaN                  Müstair
# 111      2623   2623.0       NaN      NaN     NaN                 Oberwald
# 112      2634   2634.0    6169.0   1181.0     NaN                    Emmen
# 113      2635   2635.0       NaN      NaN     NaN        Einsiedeln, Gross
# 114      2640      NaN       NaN   1504.0     NaN  Delémont, Pré-Guillaume
#
#     hydrowater_body     lon     lat  area_camels  ...  lon_naduf lat_naduf  \
# 0             Rhône  557660  133280       5239.4  ...   557660.0  133280.0
# 1             Rhône  593770  118630       3372.4  ...        NaN       NaN
# 2              Aare  657000  259360      11681.3  ...   657000.0  259360.0
# 3             Reuss  662830  252580       3385.8  ...   662830.0  252580.0
# 4              Aare  649930  177380        555.2  ...        NaN       NaN
# ..              ...     ...     ...          ...  ...        ...       ...
# 110             Rom  830800  168700        128.6  ...        NaN       NaN
# 111           Rhone  669900  154075         93.3  ...        NaN       NaN
# 112     Kleine Emme  663700  213630        478.3  ...   663700.0  213630.0
# 113       Grossbach  700710  218125          8.9  ...        NaN       NaN
# 114           Sorne  593380  245940        213.9  ...        NaN       NaN
#
#     area_naduf bafu_naduf_distance        nawa_station  lon_nawa  lat_nawa  \
# 0       5239.4                 0.0       Porte du Scex  557660.0  133280.0
# 1          NaN                 NaN                Sion  593277.0  118449.0
# 2      11681.3                 0.0               Brugg  657000.0  259360.0
# 3       3385.8                 0.0          Gebenstorf  659450.0  258850.0
# 4          NaN                 NaN  Brienzerseeeinlauf  646692.0  177000.0
# ..         ...                 ...                 ...       ...       ...
# 110        NaN                 NaN                 NaN       NaN       NaN
# 111        NaN                 NaN                 NaN       NaN       NaN
# 112      478.3                 0.0        Emmen-Littau  663917.0  213356.0
# 113        NaN                 NaN                 NaN       NaN       NaN
# 114        NaN                 NaN            Delémont  593800.0  246600.0
#
#         area_nawa bafu_nawa_distance remarks.1
# 0     5239.402096                0.0       NaN
# 1     3372.417040                0.0       NaN
# 2    11681.282882                0.0       NaN
# 3     3420.503458               10.0       NaN
# 4      555.808970                3.3       NaN
# ..            ...                ...       ...
# 110           NaN                NaN       NaN
# 111           NaN                NaN       NaN
# 112    478.277165                0.6       NaN
# 113           NaN                NaN       NaN
# 114    213.930000                0.7       NaN
#
# [115 rows x 31 columns]

# %%
# The majority is primarly formed by the bafu id, so here we check the oens that ARE NOT:
network_camels_ch_chem[network_camels_ch_chem.bafu_id.isna()]
# Out:
#      basin_id  bafu_id  naduf_id  nawa_id isot_id  \
# 10       2053      NaN       NaN   3860.0     NaN
# 12       2063      NaN       NaN   1108.0     NaN
# 19       2099      NaN       NaN   1053.0     NaN
# 20       2102      NaN       NaN   5023.0     NaN
# 26       2122      NaN       NaN   1494.0     NaN
# 27       2125      NaN       NaN   1265.0     NaN
# 35       2155      NaN       NaN   6315.0     NaN
# 37       2160      NaN       NaN   2025.0     NaN
# 45       2202      NaN       NaN   1307.0     NaN
# 46       2203      NaN       NaN   2115.0     NaN
# 49       2215      NaN       NaN   1912.0     NaN
# 61       2312      NaN       NaN   1402.0     NaN
# 64       2346      NaN       NaN   3938.0     NaN
# 69       2368      NaN       NaN   2035.0     NaN
# 74       2387      NaN       NaN   6055.0     NaN
# 77       2412      NaN       NaN   1779.0     NaN
# 80       2420      NaN       NaN   2033.0     NaN
# 84       2450      NaN       NaN   1387.0     NaN
# 86       2458      NaN       NaN   1458.0     NaN
# 89       2468      NaN       NaN   3006.0     NaN
# 90       2469      NaN       NaN   3769.0     NaN
# 92       2475      NaN       NaN   6060.0     NaN
# 93       2477      NaN       NaN   1264.0     NaN
# 94       2478      NaN       NaN   1497.0     NaN
# 95       2480      NaN       NaN   1476.0     NaN
# 98       2486      NaN       NaN   1528.0     NaN
# 99       2488      NaN       NaN   1919.0     NaN
# 106      2610      NaN       NaN   6057.0     NaN
# 114      2640      NaN       NaN   1504.0     NaN
#
#                    hydro_station hydrowater_body     lon     lat  area_camels  \
# 10   Martigny, Pont de Rossettan          Drance  570930  105200        675.7
# 12                    Murgenthal            Aare  629665  235150      10059.4
# 19             Zürich, Unterhard          Limmat  682055  249430       2173.9
# 20                        Sarnen       Sarner Aa  661460  194220        269.3
# 26           Moutier, La Charrue           Birse  595740  237010        185.8
# 27                    Frauenthal           Lorze  674715  229845        261.7
# 35         Wiler, Limpachmündung            Emme  608220  223240        924.1
# 37        Broc, Château d'en bas          Sarine  573520  161345        636.2
# 45                       Liestal          Ergolz  622270  259750        261.2
# 46                         Aigle      Grande Eau  563960  129860        131.6
# 49                        Laupen           Saane  584440  195300       1861.8
# 61          Salmsach, Hungerbühl            Aach  744410  268400         47.4
# 64                          Brig  Rhone (Rotten)  641340  129700        906.1
# 69              Locarno, Solduno          Maggia  703100  113860        928.8
# 74                     Fürstenau     Hinterrhein  753570  175730       1576.9
# 77             Vuippens, Château          Sionge  572420  167540         43.4
# 80              Lumino, Sassello           Moesa  724765  120360        471.9
# 84                      Zofingen          Wigger  637580  237080        366.2
# 86                      Valangin           Seyon  559370  206810        112.3
# 89      St. Gallen, Bruggen / Au          Sitter  742540  253230        261.1
# 90                      Hondrich          Kander  617790  168400        490.7
# 92         Bignasco, Ponte nuovo          Maggia  690040  132550        315.5
# 93                    Zug, Letzi           Lorze  680600  226070        100.2
# 94     Soyhières, Bois du Treuil           Birse  596780  249070        569.5
# 95                        Boudry          Areuse  554350  199940        377.7
# 98                  Vevey, Copet         Veveyse  554675  146565         64.5
# 99                    Latterbach           Simme  610680  167840        563.2
# 106                      Vicques        Scheulte  599485  244150         72.7
# 114      Delémont, Pré-Guillaume           Sorne  593380  245940        213.9
#
#      ...  lon_naduf lat_naduf area_naduf bafu_naduf_distance  \
# 10   ...        NaN       NaN        NaN                 NaN
# 12   ...        NaN       NaN        NaN                 NaN
# 19   ...        NaN       NaN        NaN                 NaN
# 20   ...        NaN       NaN        NaN                 NaN
# 26   ...        NaN       NaN        NaN                 NaN
# 27   ...        NaN       NaN        NaN                 NaN
# 35   ...        NaN       NaN        NaN                 NaN
# 37   ...        NaN       NaN        NaN                 NaN
# 45   ...        NaN       NaN        NaN                 NaN
# 46   ...        NaN       NaN        NaN                 NaN
# 49   ...        NaN       NaN        NaN                 NaN
# 61   ...        NaN       NaN        NaN                 NaN
# 64   ...        NaN       NaN        NaN                 NaN
# 69   ...        NaN       NaN        NaN                 NaN
# 74   ...        NaN       NaN        NaN                 NaN
# 77   ...        NaN       NaN        NaN                 NaN
# 80   ...        NaN       NaN        NaN                 NaN
# 84   ...        NaN       NaN        NaN                 NaN
# 86   ...        NaN       NaN        NaN                 NaN
# 89   ...        NaN       NaN        NaN                 NaN
# 90   ...        NaN       NaN        NaN                 NaN
# 92   ...        NaN       NaN        NaN                 NaN
# 93   ...        NaN       NaN        NaN                 NaN
# 94   ...        NaN       NaN        NaN                 NaN
# 95   ...        NaN       NaN        NaN                 NaN
# 98   ...        NaN       NaN        NaN                 NaN
# 99   ...        NaN       NaN        NaN                 NaN
# 106  ...        NaN       NaN        NaN                 NaN
# 114  ...        NaN       NaN        NaN                 NaN
#
#                            nawa_station  lon_nawa  lat_nawa     area_nawa  \
# 10                             Martigny  570930.0  105200.0    675.654142
# 12                           Murgenthal  629760.0  235242.0  10059.355199
# 19                          Hönggersteg  679609.0  250356.0   2186.067125
# 20                     Sarnen, Kägiswil  662600.0  195770.0    284.246739
# 26   Choindez- Aval de la Roche St-Jean  596293.0  240496.0    198.704397
# 27                           Frauenthal  674725.0  229850.0    261.723315
# 35    Gerlafingen, Brücke nach Biberist  609527.0  225566.0    924.578661
# 37              Broc, Halte des Marches  573520.0  161345.0    636.248285
# 45                      Augst, Autobahn  620950.0  264930.0    284.647126
# 46                     Aigle, Autoroute  561112.0  130518.0    144.375806
# 49                         Marfeldingen  585905.0  203017.0   1892.862106
# 61                             Salmsach  744400.0  268400.0     47.384256
# 64                      Amont STEP Brig  639626.0  128790.0    909.191710
# 69                     Locarno, Solduno  703100.0  113860.0    928.838504
# 74                        Rothenbrunnen  751350.0  181750.0   1663.695398
# 77                             Vuippens  572350.0  167620.0     43.397541
# 80                               Lumino  724765.0  120360.0    471.867909
# 84                             Zofingen  637200.0  238425.0    367.658360
# 86                             Valangin  559360.0  206810.0    112.314248
# 89                             Leebrugg  745500.0  258330.0    287.820335
# 90                    Brücke bei Aeschi  618676.0  166822.0    487.086478
# 92                            Brontallo  692895.0  134921.0    170.941208
# 93                                Letzi  680625.0  226100.0    100.246610
# 94                    Les Riedes-Dessus  597675.0  249340.0    572.780409
# 95                       Boudry, Brücke  554370.0  199950.0    377.675056
# 98                                Vevey  553703.0  145714.0     64.997644
# 99                           Latterbach  612505.0  168441.0    568.657968
# 106                             Vicques  599485.0  244150.0     72.695840
# 114                            Delémont  593800.0  246600.0    213.930000
#
#     bafu_nawa_distance       remarks.1
# 10                 0.0             NaN
# 12                 0.3             NaN
# 19                 2.7             NaN
# 20                 2.1             NaN
# 26                 3.9             NaN
# 27                 0.0             NaN
# 35                 3.3  Q from id_0155
# 37                 0.0             NaN
# 45                 5.9             NaN
# 46                 3.0             NaN
# 49                 8.8             NaN
# 61                 0.3             NaN
# 64                 2.0             NaN
# 69                 0.0             NaN
# 74                 6.5             NaN
# 77                 0.1             NaN
# 80                 0.0             NaN
# 84                 1.4             NaN
# 86                 0.4             NaN
# 89                 9.3             NaN
# 90                 2.0             NaN
# 92                 2.9             NaN
# 93                 0.0             NaN
# 94                 1.3             NaN
# 95                 0.0             NaN
# 98                 1.4             NaN
# 99                 2.0             NaN
# 106                0.0             NaN
# 114                0.7             NaN
#
# [29 rows x 31 columns]

# %%
# Merge the DataFrames for achieving the bafu_id ias the last column
catchments_gve = pd.merge(catchments_gve, network_camels_ch_chem[['bafu_id', 'basin_id']], on='bafu_id', how='left')
catchments_gve = pd.merge(catchments_gve, network_camels_ch_chem[['nawa_id', 'basin_id']], on='nawa_id', how='left')
catchments_gve = pd.merge(catchments_gve, network_camels_ch_chem[['naduf_id', 'basin_id']], on='naduf_id', how='left')

catchments_gve
# Out:
#      naduf_id     naduf_name   water_body     Shape_Leng       ID  gauge_id  \
# 0        1837  Porte_du_Scex        Rhône  581764.280706  nd_1837       0.0
# 1        1833          Brugg         Aare  827826.334191  nd_1833       0.0
# 2        1835      Mellingen        Reuss  423443.101185  nd_1835       0.0
# 3        1823    Andelfingen         Thur  278840.437214  nd_1823       0.0
# 4        1842        Martina          Inn  293426.137861  nd_1842       0.0
# ..        ...            ...          ...            ...      ...       ...
# 182         0           None        Simme  151671.931781  nw_1919       0.0
# 183         0           None        Sorne   82837.276182  nw_1504       0.0
# 184         0           None         Aare  745868.466423  nw_1142       0.0
# 185         0           None       Drance  138710.844326  nw_3860       0.0
# 186         0           None  Kleine_Emme  142184.941396  nw_1181       0.0
#
#     gauge_name  nawa_id     nawa_name     Shape_Le_1  ...  gve_2018_h  \
# 0         None      0.0          None  581812.194190  ...    0.072648
# 1         None      0.0          None  827842.590414  ...    0.486703
# 2         None      0.0          None  423447.043212  ...    0.429399
# 3         None      0.0          None  278852.096268  ...    0.873069
# 4         None      0.0          None  293431.436471  ...    0.058582
# ..         ...      ...           ...            ...  ...         ...
# 182       None   1919.0    Latterbach  151676.136857  ...    0.259942
# 183       None   1504.0      Delémont   82838.882339  ...    0.438026
# 184       None   1142.0         Nidau  745881.109854  ...    0.378388
# 185       None   3860.0      Martigny  138730.554523  ...    0.074332
# 186       None   1181.0  Emmen-Littau  142185.158427  ...    0.725594
#
#      gve_2019_h  gve_2020_h  gve_2021_h  gve_2022_h  \
# 0      0.071371    0.071871    0.071714    0.071609
# 1      0.480337    0.477349    0.479700    0.484112
# 2      0.425385    0.422040    0.424314    0.422356
# 3      0.858348    0.855597    0.869395    0.868562
# 4      0.057470    0.055563    0.055084    0.055510
# ..          ...         ...         ...         ...
# 182    0.255896    0.251801    0.254637    0.256755
# 183    0.431327    0.426675    0.424547    0.431703
# 184    0.374406    0.371942    0.373288    0.379099
# 185    0.072997    0.072378    0.072555    0.073715
# 186    0.715432    0.712891    0.716207    0.717919
#
#                                               geometry  bafu_id  basin_id_x  \
# 0    POLYGON Z ((2674253.038 1167429.881 0.000, 267...      0.0         NaN
# 1    POLYGON Z ((2655969.680 1259695.589 0.000, 265...      0.0         NaN
# 2    POLYGON Z ((2663723.380 1252919.068 0.000, 266...      0.0         NaN
# 3    POLYGON Z ((2719445.088 1279260.056 0.000, 271...      0.0         NaN
# 4    POLYGON Z ((2818919.419 1201129.962 0.000, 281...      0.0         NaN
# ..                                                 ...      ...         ...
# 182  POLYGON Z ((2605018.868 1172839.620 0.000, 260...      0.0         NaN
# 183  POLYGON Z ((2584725.396 1248420.902 0.000, 258...      0.0         NaN
# 184  POLYGON Z ((2597091.802 1231250.148 0.000, 259...      0.0         NaN
# 185  POLYGON Z ((2583409.306 1108018.362 0.000, 258...      0.0         NaN
# 186  POLYGON Z ((2653429.237 1216261.807 0.000, 265...      0.0         NaN
#
#      basin_id_y  basin_id
# 0           NaN    2009.0
# 1           NaN    2016.0
# 2           NaN    2018.0
# 3           NaN    2044.0
# 4           NaN    2067.0
# ..          ...       ...
# 182      2488.0       NaN
# 183      2640.0       NaN
# 184      2029.0       NaN
# 185      2053.0       NaN
# 186      2634.0       NaN
#
# [187 rows x 78 columns]

# %%
# Replace all 0s with NaN:
catchments_gve.loc[:, ['gauge_id', "naduf_id", "nawa_id"]] = catchments_gve.loc[:, ['gauge_id', "naduf_id", "nawa_id"]].replace(0, np.nan)

# %%
# Create the new 'basin_id' column based on the priority order
catchments_gve['basin_id_new'] = np.nan
catchments_gve['basin_id_new'] = np.where(
    catchments_gve['gauge_id'].notna(), catchments_gve['basin_id_x'],
    np.where(
        catchments_gve['nawa_id'].notna(), catchments_gve['basin_id_y'],
        catchments_gve['basin_id']
    )
)

# Display the updated DataFrame
catchments_gve
# Out:
#      naduf_id     naduf_name   water_body     Shape_Leng       ID  gauge_id  \
# 0      1837.0  Porte_du_Scex        Rhône  581764.280706  nd_1837       NaN
# 1      1833.0          Brugg         Aare  827826.334191  nd_1833       NaN
# 2      1835.0      Mellingen        Reuss  423443.101185  nd_1835       NaN
# 3      1823.0    Andelfingen         Thur  278840.437214  nd_1823       NaN
# 4      1842.0        Martina          Inn  293426.137861  nd_1842       NaN
# ..        ...            ...          ...            ...      ...       ...
# 182       NaN           None        Simme  151671.931781  nw_1919       NaN
# 183       NaN           None        Sorne   82837.276182  nw_1504       NaN
# 184       NaN           None         Aare  745868.466423  nw_1142       NaN
# 185       NaN           None       Drance  138710.844326  nw_3860       NaN
# 186       NaN           None  Kleine_Emme  142184.941396  nw_1181       NaN
#
#     gauge_name  nawa_id     nawa_name     Shape_Le_1  ...  gve_2019_h  \
# 0         None      NaN          None  581812.194190  ...    0.071371
# 1         None      NaN          None  827842.590414  ...    0.480337
# 2         None      NaN          None  423447.043212  ...    0.425385
# 3         None      NaN          None  278852.096268  ...    0.858348
# 4         None      NaN          None  293431.436471  ...    0.057470
# ..         ...      ...           ...            ...  ...         ...
# 182       None   1919.0    Latterbach  151676.136857  ...    0.255896
# 183       None   1504.0      Delémont   82838.882339  ...    0.431327
# 184       None   1142.0         Nidau  745881.109854  ...    0.374406
# 185       None   3860.0      Martigny  138730.554523  ...    0.072997
# 186       None   1181.0  Emmen-Littau  142185.158427  ...    0.715432
#
#      gve_2020_h  gve_2021_h  gve_2022_h  \
# 0      0.071871    0.071714    0.071609
# 1      0.477349    0.479700    0.484112
# 2      0.422040    0.424314    0.422356
# 3      0.855597    0.869395    0.868562
# 4      0.055563    0.055084    0.055510
# ..          ...         ...         ...
# 182    0.251801    0.254637    0.256755
# 183    0.426675    0.424547    0.431703
# 184    0.371942    0.373288    0.379099
# 185    0.072378    0.072555    0.073715
# 186    0.712891    0.716207    0.717919
#
#                                               geometry  bafu_id  basin_id_x  \
# 0    POLYGON Z ((2674253.038 1167429.881 0.000, 267...      0.0         NaN
# 1    POLYGON Z ((2655969.680 1259695.589 0.000, 265...      0.0         NaN
# 2    POLYGON Z ((2663723.380 1252919.068 0.000, 266...      0.0         NaN
# 3    POLYGON Z ((2719445.088 1279260.056 0.000, 271...      0.0         NaN
# 4    POLYGON Z ((2818919.419 1201129.962 0.000, 281...      0.0         NaN
# ..                                                 ...      ...         ...
# 182  POLYGON Z ((2605018.868 1172839.620 0.000, 260...      0.0         NaN
# 183  POLYGON Z ((2584725.396 1248420.902 0.000, 258...      0.0         NaN
# 184  POLYGON Z ((2597091.802 1231250.148 0.000, 259...      0.0         NaN
# 185  POLYGON Z ((2583409.306 1108018.362 0.000, 258...      0.0         NaN
# 186  POLYGON Z ((2653429.237 1216261.807 0.000, 265...      0.0         NaN
#
#      basin_id_y  basin_id  basin_id_new
# 0           NaN    2009.0        2009.0
# 1           NaN    2016.0        2016.0
# 2           NaN    2018.0        2018.0
# 3           NaN    2044.0        2044.0
# 4           NaN    2067.0        2067.0
# ..          ...       ...           ...
# 182      2488.0       NaN        2488.0
# 183      2640.0       NaN        2640.0
# 184      2029.0       NaN        2029.0
# 185      2053.0       NaN        2053.0
# 186      2634.0       NaN        2634.0
#
# [187 rows x 79 columns]

# %%
# Here we can check the data
catchments_gve[catchments_gve.basin_id_new.isna()]
# Out:
#      naduf_id naduf_name water_body     Shape_Leng       ID  gauge_id  \
# 84        NaN       None        Inn  155039.922745  wq_2403    2403.0
# 110       NaN       None     Limmat  373810.231279  wq_2622    2622.0
#
#       gauge_name  nawa_id nawa_name     Shape_Le_1  ...  gve_2019_h  \
# 84   Cinuos-Chel      NaN      None  155044.174307  ...    0.053227
# 110   Gebenstorf      NaN      None  373815.227518  ...    0.303180
#
#      gve_2020_h  gve_2021_h  gve_2022_h  \
# 84     0.052030    0.051674    0.051282
# 110    0.300006    0.300360    0.301248
#
#                                               geometry  bafu_id  basin_id_x  \
# 84   POLYGON Z ((2792289.295 1174479.955 0.000, 279...   2403.0         NaN
# 110  POLYGON Z ((2663067.290 1262049.881 0.000, 266...   2622.0         NaN
#
#      basin_id_y  basin_id  basin_id_new
# 84          NaN       NaN           NaN
# 110         NaN       NaN           NaN
#
# [2 rows x 79 columns]

# %%
# Here we solve it manuallly
catchments_gve.loc[84, ["basin_id_new"]] = 2403.0
catchments_gve.loc[110, ["basin_id_new"]] = 2622.0

catchments_gve[catchments_gve.basin_id_new.isna()]
# Out:
# Empty GeoDataFrame
# Columns: [naduf_id, naduf_name, water_body, Shape_Leng, ID, gauge_id, gauge_name, nawa_id, nawa_name, Shape_Le_1, Shape_Area, gve_1980_S, gve_1980_C, gve_1985_S, gve_1990_S, gve_1996_S, gve_1997_S, gve_1998_S, gve_1999_S, gve_2000_S, gve_2001_S, gve_2002_S, gve_2003_S, gve_2004_S, gve_2005_S, gve_2006_S, gve_2007_S, gve_2008_S, gve_2009_S, gve_2010_S, gve_2011_S, gve_2012_S, gve_2013_S, gve_2014_S, gve_2015_S, gve_2016_S, gve_2017_S, gve_2018_S, gve_2019_S, gve_2020_S, gve_2021_S, gve_2022_S, gve_Area_C, gve_1980_h, gve_1985_h, gve_1990_h, gve_1996_h, gve_1997_h, gve_1998_h, gve_1999_h, gve_2000_h, gve_2001_h, gve_2002_h, gve_2003_h, gve_2004_h, gve_2005_h, gve_2006_h, gve_2007_h, gve_2008_h, gve_2009_h, gve_2010_h, gve_2011_h, gve_2012_h, gve_2013_h, gve_2014_h, gve_2015_h, gve_2016_h, gve_2017_h, gve_2018_h, gve_2019_h, gve_2020_h, gve_2021_h, gve_2022_h, geometry, bafu_id, basin_id_x, basin_id_y, basin_id, basin_id_new]
# Index: []
#
# [0 rows x 79 columns]

# %%
# Drop duplicates based on 'gauge_id'
catchments_gve_unique = catchments_gve.drop_duplicates(subset="basin_id_new")
catchments_gve_unique.set_index("basin_id_new", inplace=True)
catchments_gve_unique
# Out:
#               naduf_id     naduf_name water_body     Shape_Leng       ID  \
# basin_id_new
# 2009.0          1837.0  Porte_du_Scex      Rhône  581764.280706  nd_1837
# 2016.0          1833.0          Brugg       Aare  827826.334191  nd_1833
# 2018.0          1835.0      Mellingen      Reuss  423443.101185  nd_1835
# 2044.0          1823.0    Andelfingen       Thur  278840.437214  nd_1823
# 2067.0          1842.0        Martina        Inn  293426.137861  nd_1842
# ...                ...            ...        ...            ...      ...
# 2478.0             NaN           None      Birse  151334.111214  nw_1497
# 2486.0             NaN           None    Veveyse   50534.896959  nw_1528
# 2488.0             NaN           None      Simme  151671.931781  nw_1919
# 2640.0             NaN           None      Sorne   82837.276182  nw_1504
# 2053.0             NaN           None     Drance  138710.844326  nw_3860
#
#               gauge_id gauge_name  nawa_id          nawa_name     Shape_Le_1  \
# basin_id_new
# 2009.0             NaN       None      NaN               None  581812.194190
# 2016.0             NaN       None      NaN               None  827842.590414
# 2018.0             NaN       None      NaN               None  423447.043212
# 2044.0             NaN       None      NaN               None  278852.096268
# 2067.0             NaN       None      NaN               None  293431.436471
# ...                ...        ...      ...                ...            ...
# 2478.0             NaN       None   1497.0  Les Riedes-Dessus  151336.979890
# 2486.0             NaN       None   1528.0              Vevey   50536.425993
# 2488.0             NaN       None   1919.0         Latterbach  151676.136857
# 2640.0             NaN       None   1504.0           Delémont   82838.882339
# 2053.0             NaN       None   3860.0           Martigny  138730.554523
#
#               ...  gve_2018_h  gve_2019_h  gve_2020_h  gve_2021_h  gve_2022_h  \
# basin_id_new  ...
# 2009.0        ...    0.072648    0.071371    0.071871    0.071714    0.071609
# 2016.0        ...    0.486703    0.480337    0.477349    0.479700    0.484112
# 2018.0        ...    0.429399    0.425385    0.422040    0.424314    0.422356
# 2044.0        ...    0.873069    0.858348    0.855597    0.869395    0.868562
# 2067.0        ...    0.058582    0.057470    0.055563    0.055084    0.055510
# ...           ...         ...         ...         ...         ...         ...
# 2478.0        ...    0.408785    0.401163    0.395319    0.395060    0.402401
# 2486.0        ...    0.247284    0.255509    0.245346    0.246707    0.250338
# 2488.0        ...    0.259942    0.255896    0.251801    0.254637    0.256755
# 2640.0        ...    0.438026    0.431327    0.426675    0.424547    0.431703
# 2053.0        ...    0.074332    0.072997    0.072378    0.072555    0.073715
#
#                                                        geometry  bafu_id  \
# basin_id_new
# 2009.0        POLYGON Z ((2674253.038 1167429.881 0.000, 267...      0.0
# 2016.0        POLYGON Z ((2655969.680 1259695.589 0.000, 265...      0.0
# 2018.0        POLYGON Z ((2663723.380 1252919.068 0.000, 266...      0.0
# 2044.0        POLYGON Z ((2719445.088 1279260.056 0.000, 271...      0.0
# 2067.0        POLYGON Z ((2818919.419 1201129.962 0.000, 281...      0.0
# ...                                                         ...      ...
# 2478.0        POLYGON Z ((2593469.122 1251650.273 0.000, 259...      0.0
# 2486.0        POLYGON Z ((2558881.297 1155690.085 0.000, 255...      0.0
# 2488.0        POLYGON Z ((2605018.868 1172839.620 0.000, 260...      0.0
# 2640.0        POLYGON Z ((2584725.396 1248420.902 0.000, 258...      0.0
# 2053.0        POLYGON Z ((2583409.306 1108018.362 0.000, 258...      0.0
#
#               basin_id_x  basin_id_y  basin_id
# basin_id_new
# 2009.0               NaN         NaN    2009.0
# 2016.0               NaN         NaN    2016.0
# 2018.0               NaN         NaN    2018.0
# 2044.0               NaN         NaN    2044.0
# 2067.0               NaN         NaN    2067.0
# ...                  ...         ...       ...
# 2478.0               NaN      2478.0       NaN
# 2486.0               NaN      2486.0       NaN
# 2488.0               NaN      2488.0       NaN
# 2640.0               NaN      2640.0       NaN
# 2053.0               NaN      2053.0       NaN
#
# [117 rows x 78 columns]

# %%
# Delete the 2403 (BAFU) since it is empty for our time range, and 2622 (merged with 2243):
catchments_gve_unique.drop(2403.0, axis=0, inplace=True)
catchments_gve_unique.drop(2622.0, axis=0, inplace=True)

# %%
catchments_gve_unique
# Out:
#               naduf_id     naduf_name water_body     Shape_Leng       ID  \
# basin_id_new
# 2009.0          1837.0  Porte_du_Scex      Rhône  581764.280706  nd_1837
# 2016.0          1833.0          Brugg       Aare  827826.334191  nd_1833
# 2018.0          1835.0      Mellingen      Reuss  423443.101185  nd_1835
# 2044.0          1823.0    Andelfingen       Thur  278840.437214  nd_1823
# 2067.0          1842.0        Martina        Inn  293426.137861  nd_1842
# ...                ...            ...        ...            ...      ...
# 2478.0             NaN           None      Birse  151334.111214  nw_1497
# 2486.0             NaN           None    Veveyse   50534.896959  nw_1528
# 2488.0             NaN           None      Simme  151671.931781  nw_1919
# 2640.0             NaN           None      Sorne   82837.276182  nw_1504
# 2053.0             NaN           None     Drance  138710.844326  nw_3860
#
#               gauge_id gauge_name  nawa_id          nawa_name     Shape_Le_1  \
# basin_id_new
# 2009.0             NaN       None      NaN               None  581812.194190
# 2016.0             NaN       None      NaN               None  827842.590414
# 2018.0             NaN       None      NaN               None  423447.043212
# 2044.0             NaN       None      NaN               None  278852.096268
# 2067.0             NaN       None      NaN               None  293431.436471
# ...                ...        ...      ...                ...            ...
# 2478.0             NaN       None   1497.0  Les Riedes-Dessus  151336.979890
# 2486.0             NaN       None   1528.0              Vevey   50536.425993
# 2488.0             NaN       None   1919.0         Latterbach  151676.136857
# 2640.0             NaN       None   1504.0           Delémont   82838.882339
# 2053.0             NaN       None   3860.0           Martigny  138730.554523
#
#               ...  gve_2018_h  gve_2019_h  gve_2020_h  gve_2021_h  gve_2022_h  \
# basin_id_new  ...
# 2009.0        ...    0.072648    0.071371    0.071871    0.071714    0.071609
# 2016.0        ...    0.486703    0.480337    0.477349    0.479700    0.484112
# 2018.0        ...    0.429399    0.425385    0.422040    0.424314    0.422356
# 2044.0        ...    0.873069    0.858348    0.855597    0.869395    0.868562
# 2067.0        ...    0.058582    0.057470    0.055563    0.055084    0.055510
# ...           ...         ...         ...         ...         ...         ...
# 2478.0        ...    0.408785    0.401163    0.395319    0.395060    0.402401
# 2486.0        ...    0.247284    0.255509    0.245346    0.246707    0.250338
# 2488.0        ...    0.259942    0.255896    0.251801    0.254637    0.256755
# 2640.0        ...    0.438026    0.431327    0.426675    0.424547    0.431703
# 2053.0        ...    0.074332    0.072997    0.072378    0.072555    0.073715
#
#                                                        geometry  bafu_id  \
# basin_id_new
# 2009.0        POLYGON Z ((2674253.038 1167429.881 0.000, 267...      0.0
# 2016.0        POLYGON Z ((2655969.680 1259695.589 0.000, 265...      0.0
# 2018.0        POLYGON Z ((2663723.380 1252919.068 0.000, 266...      0.0
# 2044.0        POLYGON Z ((2719445.088 1279260.056 0.000, 271...      0.0
# 2067.0        POLYGON Z ((2818919.419 1201129.962 0.000, 281...      0.0
# ...                                                         ...      ...
# 2478.0        POLYGON Z ((2593469.122 1251650.273 0.000, 259...      0.0
# 2486.0        POLYGON Z ((2558881.297 1155690.085 0.000, 255...      0.0
# 2488.0        POLYGON Z ((2605018.868 1172839.620 0.000, 260...      0.0
# 2640.0        POLYGON Z ((2584725.396 1248420.902 0.000, 258...      0.0
# 2053.0        POLYGON Z ((2583409.306 1108018.362 0.000, 258...      0.0
#
#               basin_id_x  basin_id_y  basin_id
# basin_id_new
# 2009.0               NaN         NaN    2009.0
# 2016.0               NaN         NaN    2016.0
# 2018.0               NaN         NaN    2018.0
# 2044.0               NaN         NaN    2044.0
# 2067.0               NaN         NaN    2067.0
# ...                  ...         ...       ...
# 2478.0               NaN      2478.0       NaN
# 2486.0               NaN      2486.0       NaN
# 2488.0               NaN      2488.0       NaN
# 2640.0               NaN      2640.0       NaN
# 2053.0               NaN      2053.0       NaN
#
# [115 rows x 78 columns]

# %%
livestock_df = pd.DataFrame(index=network_camels_ch_chem.basin_id.astype(float))

livestock_df[['gve_1980_S', 'gve_1985_S', 'gve_1990_S', 'gve_1996_S', 'gve_1997_S', 'gve_1998_S', 'gve_1999_S', 'gve_2000_S', 
              'gve_2001_S', 'gve_2002_S', 'gve_2003_S', 'gve_2004_S', 'gve_2005_S', 'gve_2006_S',
       'gve_2007_S', 'gve_2008_S', 'gve_2009_S', 'gve_2010_S', 'gve_2011_S', 'gve_2012_S', 'gve_2013_S', 
       'gve_2014_S', 'gve_2015_S', 'gve_2016_S', 'gve_2017_S', 'gve_2018_S', 'gve_2019_S', 'gve_2020_S', 'gve_2021_S',
       'gve_2022_S',
       'gve_1980_h', 'gve_1985_h', 'gve_1990_h',
       'gve_1996_h', 'gve_1997_h', 'gve_1998_h', 'gve_1999_h', 'gve_2000_h',
       'gve_2001_h', 'gve_2002_h', 'gve_2003_h', 'gve_2004_h', 'gve_2005_h',
       'gve_2006_h', 'gve_2007_h', 'gve_2008_h', 'gve_2009_h', 'gve_2010_h',
       'gve_2011_h', 'gve_2012_h', 'gve_2013_h', 'gve_2014_h', 'gve_2015_h',
       'gve_2016_h', 'gve_2017_h', 'gve_2018_h', 'gve_2019_h', 'gve_2020_h',
       'gve_2021_h', 'gve_2022_h']] = catchments_gve_unique[['gve_1980_S', 'gve_1985_S', 'gve_1990_S', 'gve_1996_S', 'gve_1997_S', 'gve_1998_S', 'gve_1999_S', 'gve_2000_S', 
              'gve_2001_S', 'gve_2002_S', 'gve_2003_S', 'gve_2004_S', 'gve_2005_S', 'gve_2006_S',
       'gve_2007_S', 'gve_2008_S', 'gve_2009_S', 'gve_2010_S', 'gve_2011_S', 'gve_2012_S', 'gve_2013_S', 
       'gve_2014_S', 'gve_2015_S', 'gve_2016_S', 'gve_2017_S', 'gve_2018_S', 'gve_2019_S', 'gve_2020_S', 'gve_2021_S',
       'gve_2022_S',
       'gve_1980_h', 'gve_1985_h', 'gve_1990_h',
       'gve_1996_h', 'gve_1997_h', 'gve_1998_h', 'gve_1999_h', 'gve_2000_h',
       'gve_2001_h', 'gve_2002_h', 'gve_2003_h', 'gve_2004_h', 'gve_2005_h',
       'gve_2006_h', 'gve_2007_h', 'gve_2008_h', 'gve_2009_h', 'gve_2010_h',
       'gve_2011_h', 'gve_2012_h', 'gve_2013_h', 'gve_2014_h', 'gve_2015_h',
       'gve_2016_h', 'gve_2017_h', 'gve_2018_h', 'gve_2019_h', 'gve_2020_h',
       'gve_2021_h', 'gve_2022_h']]

# %%
# Now we can have it file by file exported

# %%
livestock_df_sum = pd.DataFrame(index=network_camels_ch_chem.basin_id.astype(float))

livestock_df_sum[['gve_1980_S', 'gve_1985_S', 'gve_1990_S', 'gve_1996_S', 'gve_1997_S', 'gve_1998_S', 'gve_1999_S', 'gve_2000_S', 
              'gve_2001_S', 'gve_2002_S', 'gve_2003_S', 'gve_2004_S', 'gve_2005_S', 'gve_2006_S',
       'gve_2007_S', 'gve_2008_S', 'gve_2009_S', 'gve_2010_S', 'gve_2011_S', 'gve_2012_S', 'gve_2013_S', 
       'gve_2014_S', 'gve_2015_S', 'gve_2016_S', 'gve_2017_S', 'gve_2018_S', 'gve_2019_S', 'gve_2020_S', 'gve_2021_S',
       'gve_2022_S']] = catchments_gve_unique[['gve_1980_S', 'gve_1985_S', 'gve_1990_S', 'gve_1996_S', 'gve_1997_S', 'gve_1998_S', 'gve_1999_S', 'gve_2000_S', 
              'gve_2001_S', 'gve_2002_S', 'gve_2003_S', 'gve_2004_S', 'gve_2005_S', 'gve_2006_S',
       'gve_2007_S', 'gve_2008_S', 'gve_2009_S', 'gve_2010_S', 'gve_2011_S', 'gve_2012_S', 'gve_2013_S', 
       'gve_2014_S', 'gve_2015_S', 'gve_2016_S', 'gve_2017_S', 'gve_2018_S', 'gve_2019_S', 'gve_2020_S', 'gve_2021_S',
       'gve_2022_S']]


livestock_df_sum
# Out:
#              gve_1980_S     gve_1985_S     gve_1990_S     gve_1996_S  \
# basin_id
# 2009.0     44419.803851   41498.105017   43451.703140   41600.828020
# 2011.0     24072.608870   22693.132684   24780.969716   24412.001877
# 2016.0    663540.687055  631968.362347  620404.526290  576650.707450
# 2018.0    170709.609154  166791.320867  165946.890476  149502.951379
# 2019.0      3766.310809    3685.863382    3952.956017    3730.083121
# ...                 ...            ...            ...            ...
# 2617.0      1509.806858    1436.049428    1718.433051    1605.456825
# 2623.0       287.092808     269.661620     274.561650     263.169499
# 2634.0     33964.081123   34272.654174   35385.334664   32379.820996
# 2635.0       123.275307     114.145046     112.148024     106.455627
# 2640.0      9836.396323    9261.378725    8870.215877    8741.163739
#
#              gve_1997_S     gve_1998_S     gve_1999_S     gve_2000_S  \
# basin_id
# 2009.0     41436.130552   40982.295106   40443.809272   39908.566867
# 2011.0     24197.004803   23857.101053   23409.732720   23038.504203
# 2016.0    568162.661905  565985.244776  578360.471134  577830.517626
# 2018.0    145784.847064  146331.912050  150073.614546  149821.604692
# 2019.0      3649.827564    3680.967627    3768.220347    3739.265282
# ...                 ...            ...            ...            ...
# 2617.0      1523.111242    1529.712425    1586.784973    1611.428826
# 2623.0       258.457877     256.281457     256.753604     259.218369
# 2634.0     31911.498200   32094.983706   33368.023172   33474.554229
# 2635.0       100.274969     100.949120     104.920667     103.984611
# 2640.0      8668.976033    8686.761277    9184.710941    9200.989445
#
#              gve_2001_S     gve_2002_S  ...     gve_2013_S     gve_2014_S  \
# basin_id                                ...
# 2009.0     40199.651647   40573.634430  ...   38406.270927   37728.171587
# 2011.0     23204.254769   23328.966871  ...   22135.045740   21568.257099
# 2016.0    587676.338669  585873.775562  ...  577903.115984  576598.709930
# 2018.0    151100.684787  151350.550289  ...  147143.338383  146181.150865
# 2019.0      3750.969479    3771.941551  ...    3568.097771    3369.758180
# ...                 ...            ...  ...            ...            ...
# 2617.0      1638.872020    1633.314135  ...    1576.663637    1524.803888
# 2623.0       261.950193     261.453973  ...     253.407363     251.761861
# 2634.0     34055.106241   34188.802418  ...   34396.668378   33799.003546
# 2635.0       104.272761     103.145638  ...     103.015428     100.590541
# 2640.0      9473.732248    9421.527581  ...    9857.909670    9691.706514
#
#              gve_2015_S     gve_2016_S     gve_2017_S     gve_2018_S  \
# basin_id
# 2009.0     36922.288896   36770.221726   37630.241766   37737.947368
# 2011.0     21174.419734   21114.652015   20947.247122   20485.183897
# 2016.0    571699.608458  566756.025645  563668.203030  562913.724005
# 2018.0    145528.695756  145811.207108  144834.426915  145391.390397
# 2019.0      3297.830804    3278.220768    3293.571143    3296.777204
# ...                 ...            ...            ...            ...
# 2617.0      1493.855990    1489.389161    1495.458560    1468.922897
# 2623.0       250.026893     250.053512     249.786938     249.429092
# 2634.0     33886.131423   34042.632665   34043.657346   34711.699532
# 2635.0       100.614186     100.493735     101.265382     102.859678
# 2640.0      9444.422584    9513.917322    9452.804959    9371.557822
#
#              gve_2019_S     gve_2020_S     gve_2021_S     gve_2022_S
# basin_id
# 2009.0     37074.327224   37334.332673   37252.732194   37198.045523
# 2011.0     20377.910121   20141.199484   20041.529338   20118.227113
# 2016.0    555550.452501  552094.453227  554813.969584  559916.905218
# 2018.0    144032.478276  142899.790433  143669.861440  143006.766115
# 2019.0      3257.864435    3176.686632    3149.118456    3164.913236
# ...                 ...            ...            ...            ...
# 2617.0      1473.383629    1428.709108    1422.936798    1397.229382
# 2623.0       245.991310     244.222932     245.221412     248.124981
# 2634.0     34225.528894   34103.997682   34262.607814   34344.503866
# 2635.0       102.923140     100.499011     101.192461     101.728319
# 2640.0      9228.243457    9128.717789    9083.185838    9236.281940
#
# [115 rows x 30 columns]

# %%
livestock_df_ha = pd.DataFrame(index=network_camels_ch_chem.basin_id.astype(float))

livestock_df_ha[['gve_1980_h', 'gve_1985_h', 'gve_1990_h',
       'gve_1996_h', 'gve_1997_h', 'gve_1998_h', 'gve_1999_h', 'gve_2000_h',
       'gve_2001_h', 'gve_2002_h', 'gve_2003_h', 'gve_2004_h', 'gve_2005_h',
       'gve_2006_h', 'gve_2007_h', 'gve_2008_h', 'gve_2009_h', 'gve_2010_h',
       'gve_2011_h', 'gve_2012_h', 'gve_2013_h', 'gve_2014_h', 'gve_2015_h',
       'gve_2016_h', 'gve_2017_h', 'gve_2018_h', 'gve_2019_h', 'gve_2020_h',
       'gve_2021_h', 'gve_2022_h']] = catchments_gve_unique[['gve_1980_h', 'gve_1985_h', 'gve_1990_h',
       'gve_1996_h', 'gve_1997_h', 'gve_1998_h', 'gve_1999_h', 'gve_2000_h',
       'gve_2001_h', 'gve_2002_h', 'gve_2003_h', 'gve_2004_h', 'gve_2005_h',
       'gve_2006_h', 'gve_2007_h', 'gve_2008_h', 'gve_2009_h', 'gve_2010_h',
       'gve_2011_h', 'gve_2012_h', 'gve_2013_h', 'gve_2014_h', 'gve_2015_h',
       'gve_2016_h', 'gve_2017_h', 'gve_2018_h', 'gve_2019_h', 'gve_2020_h',
       'gve_2021_h', 'gve_2022_h']]

livestock_df_ha
# Out:
#           gve_1980_h  gve_1985_h  gve_1990_h  gve_1996_h  gve_1997_h  \
# basin_id
# 2009.0      0.085512    0.079887    0.083648    0.080085    0.079768
# 2011.0      0.071379    0.067289    0.073480    0.072386    0.071748
# 2016.0      0.573705    0.546408    0.536411    0.498580    0.491242
# 2018.0      0.504173    0.492601    0.490107    0.441542    0.430561
# 2019.0      0.067843    0.066394    0.071205    0.067191    0.065745
# ...              ...         ...         ...         ...         ...
# 2617.0      0.117321    0.111590    0.133533    0.124754    0.118355
# 2623.0      0.030745    0.028878    0.029403    0.028183    0.027678
# 2634.0      0.709966    0.716417    0.739675    0.676850    0.667060
# 2635.0      0.137278    0.127110    0.124886    0.118547    0.111665
# 2640.0      0.459752    0.432876    0.414593    0.408561    0.405187
#
#           gve_1998_h  gve_1999_h  gve_2000_h  gve_2001_h  gve_2002_h  ...  \
# basin_id                                                              ...
# 2009.0      0.078894    0.077857    0.076827    0.077387    0.078107  ...
# 2011.0      0.070740    0.069414    0.068313    0.068805    0.069174  ...
# 2016.0      0.489359    0.500059    0.499601    0.508113    0.506555  ...
# 2018.0      0.432176    0.443227    0.442483    0.446261    0.446998  ...
# 2019.0      0.066306    0.067878    0.067356    0.067567    0.067945  ...
# ...              ...         ...         ...         ...         ...  ...
# 2617.0      0.118868    0.123303    0.125218    0.127350    0.126918  ...
# 2623.0      0.027445    0.027496    0.027760    0.028052    0.027999  ...
# 2634.0      0.670896    0.697507    0.699734    0.711869    0.714664  ...
# 2635.0      0.112416    0.116838    0.115796    0.116117    0.114862  ...
# 2640.0      0.406018    0.429292    0.430053    0.442801    0.440361  ...
#
#           gve_2013_h  gve_2014_h  gve_2015_h  gve_2016_h  gve_2017_h  \
# basin_id
# 2009.0      0.073935    0.072630    0.071078    0.070785    0.072441
# 2011.0      0.065634    0.063954    0.062786    0.062608    0.062112
# 2016.0      0.499662    0.498534    0.494300    0.490025    0.487356
# 2018.0      0.434573    0.431731    0.429804    0.430639    0.427754
# 2019.0      0.064273    0.060700    0.059404    0.059051    0.059328
# ...              ...         ...         ...         ...         ...
# 2617.0      0.122516    0.118487    0.116082    0.115735    0.116206
# 2623.0      0.027137    0.026961    0.026775    0.026778    0.026750
# 2634.0      0.719009    0.706516    0.708337    0.711608    0.711630
# 2635.0      0.114717    0.112016    0.112043    0.111908    0.112768
# 2640.0      0.460758    0.452989    0.441431    0.444679    0.441823
#
#           gve_2018_h  gve_2019_h  gve_2020_h  gve_2021_h  gve_2022_h
# basin_id
# 2009.0      0.072648    0.071371    0.071871    0.071714    0.071609
# 2011.0      0.060742    0.060424    0.059722    0.059427    0.059654
# 2016.0      0.486703    0.480337    0.477349    0.479700    0.484112
# 2018.0      0.429399    0.425385    0.422040    0.424314    0.422356
# 2019.0      0.059385    0.058684    0.057222    0.056726    0.057010
# ...              ...         ...         ...         ...         ...
# 2617.0      0.114144    0.114491    0.111019    0.110571    0.108573
# 2623.0      0.026711    0.026343    0.026154    0.026261    0.026572
# 2634.0      0.725594    0.715432    0.712891    0.716207    0.717919
# 2635.0      0.114543    0.114614    0.111914    0.112686    0.113283
# 2640.0      0.438026    0.431327    0.426675    0.424547    0.431703
#
# [115 rows x 30 columns]

# %%
for basin in tqdm.tqdm(livestock_df.index):
    livestock_df_sum_basin = pd.DataFrame(data=livestock_df_sum.loc[basin, :])

    # Use regex to extract numeric part from the index
    livestock_df_sum_basin.index = livestock_df_sum_basin.index.to_series().str.extract('(\d+)', expand=False)

    # Optionally, convert the index back to numeric type if you want them as integers
    livestock_df_sum_basin.index = pd.to_numeric(livestock_df_sum_basin.index)

    livestock_df_sum_basin.index.name = "date"

    livestock_df_sum_basin.columns = ["gve_sum"]

    livestock_df_sum_basin["gve_ha"] = livestock_df_ha.loc[basin, :].values

    livestock_df_sum_basin.index = livestock_df_sum_basin.index.astype(int)

    # Generate a full range of years from 1980 to 2019
    full_range = pd.DataFrame(index=range(1980, 2021))

    # Reindex the dataframe to include all years
    livestock_df_sum_basin_interpolated = livestock_df_sum_basin.reindex(full_range.index)

    # Interpolate missing values
    livestock_df_sum_basin_interpolated = livestock_df_sum_basin_interpolated.interpolate(method='linear')


    livestock_df_sum_basin_interpolated = livestock_df_sum_basin_interpolated.round(4)
    livestock_df_sum_basin_interpolated.index.name = "date"

    livestock_df_sum_basin_interpolated.to_csv(PATH_OUTPUT + "\\camels_ch_chem_livestock_"+str(int(basin))+".csv", encoding='latin')
# Out:
# 100%|██████████| 115/115 [00:00<00:00, 175.72it/s]

# %% [markdown]
# # End
