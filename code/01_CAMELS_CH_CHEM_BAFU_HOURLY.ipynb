# %% [markdown]
# # BAFU dataset extraction
#
# Author: Thiago Nascimento (thiago.nascimento@eawag.ch)
#
# This notebook is used to retrieve and concatenate the BAFU dataset into hourly and daily resolutions. The output is one file per catchemnt (similar to the CAMELS_CH), with 5 columns: date, electric_cond(µS/cm), pH(-), temperature(°C) & oxygen_conc(mg/l)
#
# ## Requirements
# **Python:**
#
# * Python>=3.6
# * Jupyter
# * geopandas=0.10.2
# * numpy
# * os
# * pandas=2.1.3
# * scipy=1.9.0
# * tqdm
#
# Check the Github repository for an environment.yml (for conda environments) or requirements.txt (pip) file.
#
# **Files:**
#
# *
#
#
# **Directory:**
#
# * Clone the GitHub directory locally
# * Place any third-data variables in their respective directory.
# * ONLY update the "PATH" variable in the section "Configurations", with their relative path to the EStreams directory.
#
#
# ## References
# *
# ## Observations
# *

# %% [markdown]
# # Import modules

# %%
import pandas as pd
import numpy as np
import tqdm as tqdm
import os
import glob
import warnings

# %% [markdown]
# # Configurations

# %%
# Only editable variables:
# Relative path to your local directory
PATH = ".."
# Suppress all warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# * #### The users should NOT change anything in the code below here.

# %%
# Non-editable variables:
PATH_OUTPUT = r"results\stream_water_chemistry\timeseries"

# Set the directory:
os.chdir(PATH)

# %%
os.getcwd()
# Out:
# 'c:\\Users\\nascimth\\Documents\\Thiago\\Eawag\\Python\\Scripts\\CAMELS_CH_chem'

# %% [markdown]
# # Import data
# * BAFU

# %%
# Full dataset
path = r'data\phys_daten_BAFU\phys_daten_BAFU\\'

filenames = glob.glob(path + "*.csv")
len(filenames)
# Out:
# 423

# %% [markdown]
# #### Hourly data
# * Electric conductivity

# %%
# Define the two specific words you want to filter for
word1 = 'Elektrische'
word2 = 'Stundenmittel'

# Filter CSV files based on whether their names contain both words
electric_filenames = [file for file in filenames if (word1 in file) and (word2 in file)]
len(electric_filenames)
# Out:
# 19

# %% [markdown]
# * BAFU: 2290 is located elsewhere (2290_St-Sulpice_Areuse_Eawag_CAMELS_CH)
# * NADUF: 2046, 2044 and 2045 (not BAFU).

# %% [markdown]
# * pH

# %%
# Define the two specific words you want to filter for
word1 = 'pH'
word2 = 'Stundenmittel'

# Filter CSV files based on whether their names contain both words
ph_filenames = [file for file in filenames if (word1 in file) and (word2 in file)]
ph_filenames
# Out:
# ['data\\phys_daten_BAFU\\phys_daten_BAFU\\2009_pH-Wert_Stundenmittel_1976-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2016_pH-Wert_Stundenmittel_1976-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2018_pH-Wert_Stundenmittel_1976-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2044_pH-Wert_Stundenmittel_1986-01-29_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2068_pH-Wert_Stundenmittel_1978-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2085_pH-Wert_Stundenmittel_1976-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2091_pH-Wert_Stundenmittel_1976-01-01_1978-06-30.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2130_pH-Wert_Stundenmittel_1980-07-11_1985-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2135_pH-Wert_Stundenmittel_1976-01-01_2006-02-23.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2143_pH-Wert_Stundenmittel_1976-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2174_pH-Wert_Stundenmittel_1977-04-04_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2410_pH-Wert_Stundenmittel_1991-04-12_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2415_pH-Wert_Stundenmittel_1976-03-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2462_pH-Wert_Stundenmittel_1999-03-25_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2473_pH-Wert_Stundenmittel_1976-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2613_pH-Wert_Stundenmittel_1977-01-01_2022-11-08.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2622_pH-Wert_Stundenmittel_1976-01-01_2002-08-03.csv']

# %% [markdown]
# Here we have only 2622 (2243).

# %% [markdown]
# * Temperature

# %%
# Define the two specific words you want to filter for
word1 = 'Wassertemperatur'
word2 = 'Stundenmittel'

# Filter CSV files based on whether their names contain both words
temperature_filenames = [file for file in filenames if (word1 in file) and (word2 in file)]
temperature_filenames
# Out:
# ['data\\phys_daten_BAFU\\phys_daten_BAFU\\2009_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2011_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2016_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2018_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2019_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2029_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2030_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2033_Wassertemperatur_Stundenmittel_2002-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2034_Wassertemperatur_Stundenmittel_1976-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2044_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2056_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2067_Wassertemperatur_Stundenmittel_1981-10-01_1988-11-21.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2068_Wassertemperatur_Stundenmittel_1977-05-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2070_Wassertemperatur_Stundenmittel_1976-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2084_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2085_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2091_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2104_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2106_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2109_Wassertemperatur_Stundenmittel_1986-02-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2112_Wassertemperatur_Stundenmittel_2005-06-02_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2113_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2126_Wassertemperatur_Stundenmittel_2002-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2130_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2135_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2139_Wassertemperatur_Stundenmittel_1979-03-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2143_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2150_Wassertemperatur_Stundenmittel_2003-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2152_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2159_Wassertemperatur_Stundenmittel_2006-11-15_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2161_Wassertemperatur_Stundenmittel_2003-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2167_Wassertemperatur_Stundenmittel_2002-06-13_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2170_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2174_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2179_Wassertemperatur_Stundenmittel_2003-05-09_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2181_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2190_Wassertemperatur_Stundenmittel_1974-01-01_1983-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2205_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2210_Wassertemperatur_Stundenmittel_2002-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2232_Wassertemperatur_Stundenmittel_2002-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2243_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2256_Wassertemperatur_Stundenmittel_2003-05-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2265_Wassertemperatur_Stundenmittel_2015-12-18_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2269_Wassertemperatur_Stundenmittel_1986-11-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2276_Wassertemperatur_Stundenmittel_2004-02-19_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2282_Wassertemperatur_Stundenmittel_2002-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2288_Wassertemperatur_Stundenmittel_2009-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2307_Wassertemperatur_Stundenmittel_2004-02-12_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2308_Wassertemperatur_Stundenmittel_2004-11-25_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2327_Wassertemperatur_Stundenmittel_2003-10-27_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2343_Wassertemperatur_Stundenmittel_2002-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2347_Wassertemperatur_Stundenmittel_2002-10-03_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2351_Wassertemperatur_Stundenmittel_2002-02-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2356_Wassertemperatur_Stundenmittel_2002-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2366_Wassertemperatur_Stundenmittel_2004-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2369_Wassertemperatur_Stundenmittel_2002-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2372_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2374_Wassertemperatur_Stundenmittel_2006-01-12_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2386_Wassertemperatur_Stundenmittel_2006-11-24_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2392_Wassertemperatur_Stundenmittel_1974-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2410_Wassertemperatur_Stundenmittel_1991-04-12_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2414_Wassertemperatur_Stundenmittel_2002-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2415_Wassertemperatur_Stundenmittel_1976-03-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2424_Wassertemperatur_Stundenmittel_1977-01-01_1995-06-20.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2425_Wassertemperatur_Stundenmittel_1977-06-01_2012-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2432_Wassertemperatur_Stundenmittel_2002-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2433_Wassertemperatur_Stundenmittel_2010-10-19_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2434_Wassertemperatur_Stundenmittel_2013-02-13_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2457_Wassertemperatur_Stundenmittel_1980-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2462_Wassertemperatur_Stundenmittel_1980-04-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2467_Wassertemperatur_Stundenmittel_1980-05-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2473_Wassertemperatur_Stundenmittel_1984-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2481_Wassertemperatur_Stundenmittel_1983-01-01_2022-08-01.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2485_Wassertemperatur_Stundenmittel_2002-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2493_Wassertemperatur_Stundenmittel_2011-09-09_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2500_Wassertemperatur_Stundenmittel_1988-09-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2604_Wassertemperatur_Stundenmittel_2002-06-13_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2606_Wassertemperatur_Stundenmittel_1998-05-09_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2608_Wassertemperatur_Stundenmittel_2002-05-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2609_Wassertemperatur_Stundenmittel_2002-06-13_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2612_Wassertemperatur_Stundenmittel_2003-09-19_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2613_Wassertemperatur_Stundenmittel_1995-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2615_Wassertemperatur_Stundenmittel_2003-01-01_2008-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2617_Wassertemperatur_Stundenmittel_2002-05-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2622_Wassertemperatur_Stundenmittel_1970-01-01_2003-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2623_Wassertemperatur_Stundenmittel_2003-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2634_Wassertemperatur_Stundenmittel_2012-12-11_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2635_Wassertemperatur_Stundenmittel_2012-10-25_2022-12-31.csv']

# %% [markdown]
# * BAFU: 2290 is located elsewhere (2290_St-Sulpice_Areuse_Eawag_CAMELS_CH), 2176 (Kanton ZH) is located elsewhere.
#
# * NADUF: 2046, 2044, 2045 (not BAFU).
#
# * 2622 (2243) is included in both files here for temperature, but suposelly is the same (ask Ursi again).
#
# * 2190, 2424 and 2425 are included here, but not in CAMELS or in the original list from Ursi (88 files in Hydronetz), but are in the excel and files.
#
# * This give us a total of 90 stations with temperature, which is the same number of total stations.

# %% [markdown]
# * Oxygen

# %%
# Define the two specific words you want to filter for
word1 = 'Sauerstoff'
word2 = 'Stundenmittel'

# Filter CSV files based on whether their names contain both words
oxygen_filenames = [file for file in filenames if (word1 in file) and (word2 in file)]
oxygen_filenames
# Out:
# ['data\\phys_daten_BAFU\\phys_daten_BAFU\\2009_Sauerstoff_Stundenmittel_1976-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2016_Sauerstoff_Stundenmittel_1976-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2018_Sauerstoff_Stundenmittel_1976-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2044_Sauerstoff_Stundenmittel_1986-01-29_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2068_Sauerstoff_Stundenmittel_1978-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2085_Sauerstoff_Stundenmittel_1976-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2091_Sauerstoff_Stundenmittel_1976-01-01_1978-06-30.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2130_Sauerstoff_Stundenmittel_1980-07-11_1985-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2135_Sauerstoff_Stundenmittel_1976-01-01_2006-02-23.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2143_Sauerstoff_Stundenmittel_1976-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2174_Sauerstoff_Stundenmittel_1977-04-04_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2410_Sauerstoff_Stundenmittel_1991-04-12_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2415_Sauerstoff_Stundenmittel_1976-02-24_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2462_Sauerstoff_Stundenmittel_1999-03-25_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2473_Sauerstoff_Stundenmittel_1976-01-01_2022-12-31.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2613_Sauerstoff_Stundenmittel_1977-01-01_2022-11-08.csv',
#  'data\\phys_daten_BAFU\\phys_daten_BAFU\\2622_Sauerstoff_Stundenmittel_1976-01-01_2002-08-03.csv']

# %% [markdown]
# Here we have only 2622 (2243).

# %% [markdown]
# ### Aggregation

# %% [markdown]
# * We have 90 stations in total.
# * The 88 from the temperature list + 2290 + 2176.
# * We first aggregate the data available from BAFU, then the 2 extra stations.
#
# #### - BAFU

# %%
columns_names = ["temp_sensor", "pH_sensor", "ec_sensor", "O2C_sensor"]

for filename in tqdm.tqdm(temperature_filenames):

    hourly_timeseries = pd.DataFrame(index = pd.date_range('01-01-1981','12-31-2020', freq='H'), columns=columns_names)
    
    network_filename = pd.read_csv(filename, skiprows=8, delimiter = ";", encoding='latin-1', usecols=["Zeitstempel", 
                                                                                                      "Wert"])
    network_filename["date"] = pd.to_datetime(network_filename["Zeitstempel"], format='%Y-%m-%d')
    network_filename = network_filename[["date", "Wert"]]
    network_filename.set_index("date", inplace = True)
    
    namestation = os.path.basename(filename)
    namestation = namestation.split("_", 5)[0]
    hourly_timeseries["temp_sensor"] = network_filename["Wert"]
    
    
    ###################################################
    ##  pH
    
    filenames = ph_filenames.copy()
    # List to store filenames containing the number
    matching_filenames = []

    # Iterate over filenames and check if the number is present in the first 4 characters of the file name
    for filename in filenames:
        # Extract the file name (without the path)
        file_name_only = filename.split("\\")[-1]
        # Extract the first 4 characters of the file name
        first_four_characters = file_name_only[:4]
        # Check if the number is present in the first 4 characters
        if namestation in first_four_characters:
            matching_filenames.append(filename)
    try:        
        network_filename = pd.read_csv(matching_filenames[0], skiprows=8, delimiter = ";", encoding='latin-1', usecols=["Zeitstempel", 
                                                                                                          "Wert"])
        network_filename["date"] = pd.to_datetime(network_filename["Zeitstempel"], format='%Y-%m-%d')
        network_filename = network_filename[["date", "Wert"]]
        network_filename.set_index("date", inplace = True)
        network_filename['Wert'] = pd.to_numeric(network_filename['Wert'], errors='coerce')

        hourly_timeseries["pH_sensor"] = network_filename["Wert"]      
    except: 
        1+1
        
    ###################################################
    ##  electric_cond(µS/cm)
    
    filenames = electric_filenames.copy()
    # List to store filenames containing the number
    matching_filenames = []

    # Iterate over filenames and check if the number is present in the first 4 characters of the file name
    for filename in filenames:
        # Extract the file name (without the path)
        file_name_only = filename.split("\\")[-1]
        # Extract the first 4 characters of the file name
        first_four_characters = file_name_only[:4]
        # Check if the number is present in the first 4 characters
        if namestation in first_four_characters:
            matching_filenames.append(filename)
    try:       
        network_filename = pd.read_csv(matching_filenames[0], skiprows=8, delimiter = ";", encoding='latin-1', usecols=["Zeitstempel", 
                                                                                                          "Wert"])
        network_filename["date"] = pd.to_datetime(network_filename["Zeitstempel"], format='%Y-%m-%d')
        network_filename = network_filename[["date", "Wert"]]
        network_filename.set_index("date", inplace = True)
        network_filename['Wert'] = pd.to_numeric(network_filename['Wert'], errors='coerce')

        hourly_timeseries["ec_sensor"] = network_filename["Wert"]
    except:
        1+1
    ###################################################
    ##  oxygen_conc(mg/l)
    
    filenames = oxygen_filenames.copy()
    # List to store filenames containing the number
    matching_filenames = []

    # Iterate over filenames and check if the number is present in the first 4 characters of the file name
    for filename in filenames:
        # Extract the file name (without the path)
        file_name_only = filename.split("\\")[-1]
        # Extract the first 4 characters of the file name
        first_four_characters = file_name_only[:4]
        # Check if the number is present in the first 4 characters
        if namestation in first_four_characters:
            matching_filenames.append(filename)
    try:      
        network_filename = pd.read_csv(matching_filenames[0], skiprows=8, delimiter = ";", encoding='latin-1', usecols=["Zeitstempel", 
                                                                                                          "Wert"])
        network_filename["date"] = pd.to_datetime(network_filename["Zeitstempel"], format='%Y-%m-%d')
        network_filename = network_filename[["date", "Wert"]]
        network_filename.set_index("date", inplace = True)
        network_filename['Wert'] = pd.to_numeric(network_filename['Wert'], errors='coerce')

        hourly_timeseries["O2C_sensor"] = network_filename["Wert"]  
    except: 
        1+1
    
    hourly_timeseries.index.name = "date"
    
    hourly_timeseries = hourly_timeseries.round(2)

    hourly_timeseries.to_csv(PATH_OUTPUT + "/hourly/CAMELS_CH_Chem_hourly_"+namestation+".csv", encoding='latin')
# Out:
# 100%|██████████| 88/88 [03:13<00:00,  2.19s/it]

# %% [markdown]
# #### - 2 extra stations
# Station 2176

# %%
namestation = "2176"

columns_names = ["temperature(°C)", "pH(-)", "electric_cond(µS/cm)", "oxygen_conc(mg/l)"]
hourly_timeseries = pd.DataFrame(index = pd.date_range('01-01-1981','12-31-2020', freq='H'), columns=columns_names)

path_2176 = 'data\Kanton ZH\S2176\S2176_Wassertemperatur _Stundenmittel.txt'
network_2176 = pd.read_csv(path_2176, skiprows=2, delimiter = "\t", encoding='latin-1')
network_2176["date"] = network_2176["Datum"] + " "  + network_2176["Zeit"]
network_2176["date"] = pd.to_datetime(network_2176["date"], format='%d.%m.%Y %H:%M:%S')
network_2176.set_index("date", inplace = True)
network_2176 = network_2176[["Messwert"]]
hourly_timeseries["temperature(°C)"] = network_2176["Messwert"]

hourly_timeseries.index.name = "date"
    
hourly_timeseries = hourly_timeseries.round(2)

# Rename the names of the columns
hourly_timeseries.columns = ["temp_sensor", "pH_sensor", "ec_sensor", "O2C_sensor"]

hourly_timeseries.to_csv(PATH_OUTPUT + "/hourly/CAMELS_CH_Chem_hourly_"+namestation+".csv", encoding='latin')

hourly_timeseries
# Out:
#                      temp_sensor pH_sensor ec_sensor O2C_sensor
# date
# 1981-01-01 00:00:00          NaN       NaN       NaN        NaN
# 1981-01-01 01:00:00          NaN       NaN       NaN        NaN
# 1981-01-01 02:00:00          NaN       NaN       NaN        NaN
# 1981-01-01 03:00:00          NaN       NaN       NaN        NaN
# 1981-01-01 04:00:00          NaN       NaN       NaN        NaN
# ...                          ...       ...       ...        ...
# 2020-12-30 20:00:00         3.03       NaN       NaN        NaN
# 2020-12-30 21:00:00         3.00       NaN       NaN        NaN
# 2020-12-30 22:00:00         2.98       NaN       NaN        NaN
# 2020-12-30 23:00:00         2.99       NaN       NaN        NaN
# 2020-12-31 00:00:00         3.01       NaN       NaN        NaN
#
# [350617 rows x 4 columns]

# %% [markdown]
# Station 2290

# %%
namestation = "2290"

columns_names = ["temperature(°C)", "pH(-)", "electric_cond(µS/cm)", "oxygen_conc(mg/l)"]
hourly_timeseries = pd.DataFrame(index = pd.date_range('01-01-1981','12-31-2020', freq='H'), columns=columns_names)

############ Electrical conductivity
path_2290_EC = 'data\S2290\S2290_St-Sulpice-Areuse_LF_20090425-20221231.CSV'

network_2290_EC = pd.read_csv(path_2290_EC, skiprows=13, delimiter = ";", encoding='latin-1')

network_2290_EC = network_2290_EC[["Datum.1", "Uhrzeit.1", "LF Stundenmittel [µS/cm]"]]

# Drop rows with NaN values in the specific column
network_2290_EC.dropna(subset=['Datum.1'], inplace=True)

network_2290_EC["date"] = network_2290_EC["Datum.1"] + " "  + network_2290_EC["Uhrzeit.1"]
network_2290_EC["date"] = pd.to_datetime(network_2290_EC["date"], format='%d.%m.%Y %H:%M:%S')
network_2290_EC.set_index("date", inplace = True)

############ Temperature
path_2290_T = 'data\S2290\S2290_St-Sulpice-Areuse_T_20090425-20221231.CSV'

network_2290_T = pd.read_csv(path_2290_T, skiprows=13, delimiter = ";", encoding='latin-1')

network_2290_T = network_2290_T[["Datum.1", "Uhrzeit.1", "T Stundenmittel [°C]"]]

# Drop rows with NaN values in the specific column
network_2290_T.dropna(subset=['Datum.1'], inplace=True)

network_2290_T["date"] = network_2290_T["Datum.1"] + " "  + network_2290_T["Uhrzeit.1"]
network_2290_T["date"] = pd.to_datetime(network_2290_T["date"], format='%d.%m.%Y %H:%M:%S')
network_2290_T.set_index("date", inplace = True)

############################################################################
network_2290_EC = network_2290_EC[["LF Stundenmittel [µS/cm]"]]
hourly_timeseries["electric_cond(µS/cm)"] = network_2290_EC["LF Stundenmittel [µS/cm]"]

network_2290_T = network_2290_T[["T Stundenmittel [°C]"]]
hourly_timeseries["temperature(°C)"] = network_2290_T["T Stundenmittel [°C]"]

hourly_timeseries.index.name = "date"

# There are some non-numeric things in the columns, instead of NaNs
hourly_timeseries = hourly_timeseries.apply(pd.to_numeric, errors='coerce')

hourly_timeseries = hourly_timeseries.round(2)

# Rename the names of the columns
hourly_timeseries.columns = ["temp_sensor", "pH_sensor", "ec_sensor", "O2C_sensor"]

hourly_timeseries.to_csv(PATH_OUTPUT + "/hourly/CAMELS_CH_Chem_hourly_"+namestation+".csv", encoding='latin')

hourly_timeseries
# Out:
#                      temp_sensor  pH_sensor  ec_sensor  O2C_sensor
# date
# 1981-01-01 00:00:00          NaN        NaN        NaN         NaN
# 1981-01-01 01:00:00          NaN        NaN        NaN         NaN
# 1981-01-01 02:00:00          NaN        NaN        NaN         NaN
# 1981-01-01 03:00:00          NaN        NaN        NaN         NaN
# 1981-01-01 04:00:00          NaN        NaN        NaN         NaN
# ...                          ...        ...        ...         ...
# 2020-12-30 20:00:00         7.29        NaN      411.2         NaN
# 2020-12-30 21:00:00         7.28        NaN      410.3         NaN
# 2020-12-30 22:00:00         7.27        NaN      408.2         NaN
# 2020-12-30 23:00:00         7.24        NaN      413.3         NaN
# 2020-12-31 00:00:00         7.22        NaN      413.8         NaN
#
# [350617 rows x 4 columns]

# %% [markdown]
# - Remarks
#
#     - 87 stations from BAFU in inverntarlist
#
#     - 2424 is included here, but not in the internarlist (they are in observation as if they are from other stations) (moved to another folder)
#
#     - 2622 (repetition? of 2243) (moved to another folder)
#
#     - 2403 hourly does not exist. Only daily.

# %%
hourly_timeseries.iloc[:, :] = np.nan
hourly_timeseries
# Out:
#                      temp_sensor  pH_sensor  ec_sensor  O2C_sensor
# date
# 1981-01-01 00:00:00          NaN        NaN        NaN         NaN
# 1981-01-01 01:00:00          NaN        NaN        NaN         NaN
# 1981-01-01 02:00:00          NaN        NaN        NaN         NaN
# 1981-01-01 03:00:00          NaN        NaN        NaN         NaN
# 1981-01-01 04:00:00          NaN        NaN        NaN         NaN
# ...                          ...        ...        ...         ...
# 2020-12-30 20:00:00          NaN        NaN        NaN         NaN
# 2020-12-30 21:00:00          NaN        NaN        NaN         NaN
# 2020-12-30 22:00:00          NaN        NaN        NaN         NaN
# 2020-12-30 23:00:00          NaN        NaN        NaN         NaN
# 2020-12-31 00:00:00          NaN        NaN        NaN         NaN
#
# [350617 rows x 4 columns]

# %%
hourly_timeseries.to_csv(PATH_OUTPUT + "/hourly/CAMELS_CH_Chem_hourly_2403.csv", encoding='latin')

# %%
# Merging 2622 into 2243
bafu_2622_hourly = pd.read_csv(r"results\\stream_water_chemistry\\timeseries\hourly\2190_2424_2425_2243\CAMELS_CH_chem_hourly_2622.csv", encoding='latin')
bafu_2622_hourly.set_index("date", inplace=True)
bafu_2622_hourly
# Out:
#                      temp_sensor  pH_sensor  ec_sensor  O2C_sensor
# date
# 1981-01-01 00:00:00         4.26       7.66      303.9        8.97
# 1981-01-01 01:00:00         4.24       7.66      303.1        8.97
# 1981-01-01 02:00:00         4.23       7.65      302.4        8.98
# 1981-01-01 03:00:00         4.22       7.65      301.9        9.02
# 1981-01-01 04:00:00         4.23       7.66      301.4        9.06
# ...                          ...        ...        ...         ...
# 2020-12-30 20:00:00          NaN        NaN        NaN         NaN
# 2020-12-30 21:00:00          NaN        NaN        NaN         NaN
# 2020-12-30 22:00:00          NaN        NaN        NaN         NaN
# 2020-12-30 23:00:00          NaN        NaN        NaN         NaN
# 2020-12-31 00:00:00          NaN        NaN        NaN         NaN
#
# [350617 rows x 4 columns]

# %%
# Merging 2622 into 2243
bafu_2243_hourly = pd.read_csv(r"results\\stream_water_chemistry\\timeseries\hourly/CAMELS_CH_chem_hourly_2243.csv", encoding='latin')
bafu_2243_hourly.set_index("date", inplace=True)
bafu_2243_hourly
# Out:
#                      temp_sensor  pH_sensor  ec_sensor  O2C_sensor
# date
# 1981-01-01 00:00:00         4.26        NaN        NaN         NaN
# 1981-01-01 01:00:00         4.24        NaN        NaN         NaN
# 1981-01-01 02:00:00         4.23        NaN        NaN         NaN
# 1981-01-01 03:00:00         4.22        NaN        NaN         NaN
# 1981-01-01 04:00:00         4.23        NaN        NaN         NaN
# ...                          ...        ...        ...         ...
# 2020-12-30 20:00:00         6.50        NaN        NaN         NaN
# 2020-12-30 21:00:00         6.49        NaN        NaN         NaN
# 2020-12-30 22:00:00         6.50        NaN        NaN         NaN
# 2020-12-30 23:00:00         6.52        NaN        NaN         NaN
# 2020-12-31 00:00:00         6.55        NaN        NaN         NaN
#
# [350617 rows x 4 columns]

# %%
bafu_2243_hourly["temp_sensor"].plot()
bafu_2622_hourly["temp_sensor"].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
bafu_2243_hourly["ec_sensor"] = bafu_2622_hourly["ec_sensor"]

bafu_2243_hourly["pH_sensor"] = bafu_2622_hourly["pH_sensor"]
bafu_2243_hourly["O2C_sensor"] = bafu_2622_hourly["O2C_sensor"]

# %%
bafu_2243_hourly.to_csv(r"results\\stream_water_chemistry\\timeseries\hourly/CAMELS_CH_chem_hourly_2243.csv", encoding='latin')

# %% [markdown]
# # End
