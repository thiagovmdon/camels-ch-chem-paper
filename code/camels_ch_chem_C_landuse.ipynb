# %% [markdown]
# # Landcover dataset extraction
#
# Author: Martina Kauzlaric (martina.kauzlaric@unibe.ch)
#
# This notebook is used to retrieve and concatenate the landcover dataset into a table for publication alongisde the used data.
#
# ## Requirements
# **Python:**
#
# * Python=3.13.2
# * Jupyter
# * os
# * numpy=2.2.4
# * xarray=2024.11.0
# * pandas=2.2.3
# * geopandas=1.0.1
# * tqdm=4.67.1
#
# Check the Github repository for an environment_lancover.yml and environment_camels_chem_landcover_dwnlCLMSdata.yml (here for downloading additionally the data via CLMS API) for conda environments file.
#
# **Files:**
#
# * ?
#
#
# **Directory:**
#
# * Clone the GitHub directory locally
# * Place any third-data variables in their respective directory.
# * ONLY update the "PATH" variable in the section "Configurations", with their relative path to the EStreams directory.
#
#
# ## References
# * https://land.copernicus.eu/en/products/corine-land-cover
# ## Observations
# * Part of the data is interpolated.

# %% [markdown]
# # Import modules

# %%
# Clear all variables
# %reset -f
#Import necessary libraries
import os
import glob
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd
from shapely.geometry import MultiPolygon
from shapely.geometry import box
import tqdm as tqdm

# %% [markdown]
# # Configurations

# %%
# Only editable variables:
# Set (relative) path to your local directory
# PATH = ".."
PATH = "S:\\CAMELS-CH\\CAMELS-chem"

# %%
## Set directories
GIS_dir = os.path.join(PATH,"data\\GIS")
# Define shapefile with the catchments
catchments_shp = os.path.join(GIS_dir,"shapefile_catchments\\camels_ch_chem_catchment_boundaries.shp")
#Add subfolder to GIS_dir for CORINE Landcover data
GIS_dir = os.path.join(GIS_dir, "CORINE_Landcover")  
PATH_OUTPUT = os.path.join(PATH,"results\\catchment_aggregated_data\\landcover")

# Create the directories if they do not exist
# Note: the directories are created in the order they are listed here, so if you want to change the structure, do it here.
if not os.path.isdir(GIS_dir):
    os.makedirs(GIS_dir, exist_ok=True)

if not os.path.isdir(os.path.join(PATH, "results")):
    os.makedirs(os.path.join(PATH, "results"), exist_ok=True)

if not os.path.isdir(os.path.join(PATH, "results\\catchment_aggregated_data")):
    os.makedirs(os.path.join(PATH, "results\\catchment_aggregated_data"), exist_ok=True)

if not os.path.isdir(PATH_OUTPUT):
    os.makedirs(PATH_OUTPUT, exist_ok=True)

##Change to directory to where you want to store the results    
os.chdir(PATH_OUTPUT)

# %%
os.getcwd()
# Out:
# 'S:\\CAMELS-CH\\CAMELS-chem\\results\\catchment_aggregated_data\\landuse'

# %% [markdown]
# # Download CORINE Landcover data
# * Here following the code to autmomatically download the Landcover data
# * Note: you nned to be regostered on CLMS and create an API token, plese refer to https://land.copernicus.eu/en/how-to-guides/how-to-download-spatial-data/how-to-create-api-tokens
# * after you created you private key please follow the steps here below
# * The user and alternatively also download manually the data under https://land.copernicus.eu/en/products/corine-land-cover
# => then skip this part and gp to import data!
#
# ## Requirements additionally to those listed above
# **Python:**
#
# * pyjwt= 2.10.1
# * cryptography = 44.0.1
# * fiona = 1.10.1

# %%
#Additional libraries to be uploaded if not already installed
import json
import requests
import time
import jwt  # PyJWT
from cryptography.hazmat.primitives import serialization
import zipfile
import fiona

# %%
# 1. Load your token using the private key JSON file
# Load credentials from file
with open(r"S:\CAMELS-CH\CAMELS-chem\privatekey_API_CMLS.json", "r") as f:
    creds = json.load(f)

# Prepare the JWT (JSON Web Token)
now = int(time.time())
payload = {
    "iss": creds["client_id"],
    "sub": creds["user_id"],
    "aud": creds["token_uri"],
    "iat": now,
    "exp": now + 3600,  # expires in 1 hour
}

# %%
private_key = serialization.load_pem_private_key(
    creds["private_key"].encode(), password=None
)

jwt_token = jwt.encode(payload, private_key, algorithm="RS256")

# Request the access token
response = requests.post(
    creds["token_uri"],
    data={"grant_type": "urn:ietf:params:oauth:grant-type:jwt-bearer", "assertion": jwt_token},
)

if response.ok:
    token = response.json()["access_token"]
    print("✅ Access token successfully retrieved!")
else:
    raise Exception(f"❌ Failed to get access token: {response.status_code} {response.text}")
# Out:
# ✅ Access token successfully retrieved!

# %% [markdown]
# Be careful:
# https://eea.github.io/clms-api-docs/download.html#download-prepackaged-files
#
# BoundingBox”: [max.lat,max.lon,min.lat,min.lon] which is the same as [N,E,S,W]
# Note: Longitude is typically represented by the X-coordinate, and Latitude is represented by the Y-coordinate

# %%
# 2. Load and reproject catchment shapefile
catchments = gpd.read_file(catchments_shp)
#catchments_3035 = catchments.to_crs("EPSG:3035")
# Convert geometry to GeoJSON format (MultiPolygon)
#bounds = catchments_3035.total_bounds  # [minx, miny, maxx, maxy]
#geometry_json = catchments_3035.geometry.union_all().__geo_interface__
# Transform the geometry back to WGS84 (EPSG:4326) 
# => this is the projection needed to download the data by a bounding box!!
catchments_wgs84 = catchments.to_crs("EPSG:4326")
bounds = catchments_wgs84.total_bounds
# Define the buffer amount in decimal degrees (we add some buffer to the bounds)
# Note: the buffer is in decimal degrees, so 0.1 =~ 10 km
buffer = 0.1

# Add buffer to the bounds
buffered_bounds = [
    bounds[0] - buffer,  # minx - buffer
    bounds[1] - buffer,  # miny - buffer
    bounds[2] + buffer,  # maxx + buffer
    bounds[3] + buffer,  # maxy + buffer
]

# Convert NumPy float64 to standard Python float
buffered_bounds = [float(x) for x in buffered_bounds]

# %%
print("Bounds:", bounds)
# Out:
# Bounds: [ 5.90351684 45.73174765 10.4920484  48.02963712]

# %%
print("Buffered bounds:", buffered_bounds)
# Out:
# Buffered bounds: [5.803516841915284, 45.63174764839809, 10.592048402439152, 48.12963712004709]

# %%
# 3. Setup the base request
url = "https://land.copernicus.eu/api/@datarequest_post"
headers = {
    "Accept": "application/json",
    "Content-Type": "application/json",
    "Authorization": f"Bearer {token}",
}

# %% [markdown]
# You find the **UID** (here *DataseID*) and the **@id** (here *DownloadID*) for the different datasets on https://eea.github.io/clms-api-docs/download.html#download-prepackaged-files
# under **Find the items to be downloaded**

# %%
# 4. Make list with dataset info by year (UID = Dataset ID, ID = Vector GDB ID)
datasets = {
    "2000": {
        "DatasetID": "6704f90ca82e4f228a46111519f8978e",
        "DownloadID": "1009310e-2cd8-481c-b15b-aee3f0406098"
    },
    "2006": {
        "DatasetID": "d443c86fec2f49e08ff12c7decdbf2af",
        "DownloadID": "3936f6a5-9157-4e76-9fc7-4e14668c81ef"
    },
    "2012": {
        "DatasetID": "a5ee71470be04d66bcff498f94ceb5dc",
        "DownloadID": "cff14ee5-bafb-46f4-a1b2-2cd6f4049514"
    },
    "2018": {
        "DatasetID": "0407d497d3c44bcd93ce8fd5bf78596a",
        "DownloadID": "1bda2fbd-3230-42ba-98cf-69c96ac063bc"
    },
}

# %%
# 5. #Define polling function to check if the task is completed and
# loop over each year
# # Note:this first part is not so important/optional, but it is good to keep track of the progress of the download
#   the requests will be sent anyway (even if the download takes longer than 10 minutes)
def poll_task_status(task_id, headers, max_wait=600, interval=10):
    """Poll Copernicus API until the task is ready or timeout."""
    task_url = f"https://land.copernicus.eu/api/@tasks/{task_id}"
    waited = 0

    while waited < max_wait:
        response = requests.get(task_url, headers=headers)
        if response.ok:
            status = response.json().get("Status", "").lower()
            if status == "completed":
                download_url = response.json().get("DownloadUrl")
                return download_url
            elif status == "failed":
                raise RuntimeError(f"Task {task_id} failed.")
        time.sleep(interval)
        waited += interval

    raise TimeoutError(f"Task {task_id} did not complete in time.") 

for year, ids in datasets.items():
    payload = {
        "Datasets": [ {
            "DatasetID": ids["DatasetID"],
            "DatasetDownloadInformationID": ids["DownloadID"],
            "OutputFormat": "GDB",
            "OutputGCS": "EPSG:3035",
            "BoundingBox": list(buffered_bounds)  # "BoundingBox":  must be in WGS84!!
        }]
    }

    response = requests.post(url, headers=headers, json=payload)

    if response.status_code == 201:
        task_id = response.json()["TaskIds"][0]["TaskID"]
        print(f"[{year}] Submitted task {task_id}, polling for result...")

        try:
            download_url = poll_task_status(task_id, headers)
            if download_url:
                print(f"[{year}] Ready: {download_url}")
                response_file = requests.get(download_url)
                out_path = os.path.join(PATH_OUTPUT, f"CLC_{year}.zip")
                with open(out_path, "wb") as f:
                    f.write(response_file.content)
                print(f"[{year}] Downloaded to: {out_path}")
            else:
                print(f"[{year}] No download URL found after polling.")
        except Exception as e:
            print(f"[{year}] Error: {e}")
    else:
        print(f"[{year}] Failed request: {response.status_code} - {response.text}")
# Out:
# [2000] Submitted task 53895001815, polling for result...
# [2000] Error: Task 53895001815 did not complete in time.
# [2006] Submitted task 96036197586, polling for result...
# [2006] Error: Task 96036197586 did not complete in time.
# [2012] Submitted task 13820436744, polling for result...
# [2012] Error: Task 13820436744 did not complete in time.
# [2018] Submitted task 19954247833, polling for result...
# [2018] Error: Task 19954247833 did not complete in time.

# %% [markdown]
# **Note: data might be queued,depending on the load in the CLMS download process**
#
#  *this can last 5-10min for a region like Switzerland (hydrological Switzerland is about 58'000 km^2)
#  Note: If it last longer it means you might have to adapt the length of expiry duration defined above (exp) or split the download process and regenerate the access token!*
#
#  **Once you receive the email confirming the download is ready, download the data and save them in the GIS_dir directory**

# %%
# 6. Unzip the downloaded files
import zipfile

# Folder to extract contents
extract_dir = os.path.join(GIS_dir, "CLC_downloads")
os.makedirs(extract_dir, exist_ok=True)

# Loop through and unzip
for file in os.listdir(GIS_dir):
    if file.endswith(".zip"):
        zip_path = os.path.join(GIS_dir, file)
        extract_path = os.path.join(extract_dir, file.replace(".zip", ""))
        print("Zip path:", zip_path)
        print("Extr path:", extract_path)
        os.makedirs(extract_path, exist_ok=True)

        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(extract_path)
        print(f"✅ Unzipped: {file}")
# Out:
# Zip path: S:\CAMELS-CH\CAMELS-chem\data\GIS\CORINE_Landuse\175369.zip
# Extr path: S:\CAMELS-CH\CAMELS-chem\data\GIS\CORINE_Landuse\CLC_downloads\175369
# ✅ Unzipped: 175369.zip
# Zip path: S:\CAMELS-CH\CAMELS-chem\data\GIS\CORINE_Landuse\175377.zip
# Extr path: S:\CAMELS-CH\CAMELS-chem\data\GIS\CORINE_Landuse\CLC_downloads\175377
# ✅ Unzipped: 175377.zip
# Zip path: S:\CAMELS-CH\CAMELS-chem\data\GIS\CORINE_Landuse\175386.zip
# Extr path: S:\CAMELS-CH\CAMELS-chem\data\GIS\CORINE_Landuse\CLC_downloads\175386
# ✅ Unzipped: 175386.zip
# Zip path: S:\CAMELS-CH\CAMELS-chem\data\GIS\CORINE_Landuse\175392.zip
# Extr path: S:\CAMELS-CH\CAMELS-chem\data\GIS\CORINE_Landuse\CLC_downloads\175392
# ✅ Unzipped: 175392.zip

# %%
#List zipped files in GIS_dir
zipdirs = os.listdir(GIS_dir)
zipfiles = [file for file in zipdirs if file.endswith(".zip")]
print("Zip files:", zipfiles)
# Out:
# Zip files: ['175369.zip', '175377.zip', '175386.zip', '175392.zip']

# %% [markdown]
# Let us free some space

# %%
# Delete each zip file
for zipfile in zipfiles:
    zip_path = os.path.join(GIS_dir, zipfile)
    os.remove(zip_path)
    print(f"✅ Deleted: {zipfile}")
# Out:
# ✅ Deleted: 175369.zip
# ✅ Deleted: 175377.zip
# ✅ Deleted: 175386.zip
# ✅ Deleted: 175392.zip

# %% [markdown]
# The downloaded data are .gdb, so we need to extract the data (*layer*) to a shapefile:

# %%
# Loop through unzipped folders
for root, dirs, files in os.walk(extract_dir):
    for dir_name in dirs:
        if dir_name.endswith(".gdb"):
            gdb_path = os.path.join(root, dir_name)
            print(f"📂 GDB directory found: {gdb_path}")
            # List layers
            layers = fiona.listlayers(gdb_path)
            print(f"  📄 Available layers: {layers}")

            # Export each layer to shapefile
            for layer in layers:
                gdf = gpd.read_file(gdb_path, layer=layer)
                out_shp = os.path.join(GIS_dir, f"{layer}.shp")
                gdf.to_file(out_shp)
                print(f"✅ Exported: {out_shp}")
# Out:
# 📂 GDB directory found: S:\CAMELS-CH\CAMELS-chem\data\GIS\CORINE_Landuse\CLC_downloads\175369\Results\U2006_CLC2000_V2020_20u1.gdb
#   📄 Available layers: ['U2006_CLC2000_V2020_20u1']
# C:\Users\mkauzlaric\AppData\Local\Temp\ipykernel_2296\2495070687.py:15: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf.to_file(out_shp)
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Shape_Length' to 'Shape_Leng'
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 455422915.806568444 of field Shape_Area of feature 7130 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 134675884.87484464 of field Shape_Area of feature 8482 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 754246838.576803088 of field Shape_Area of feature 8839 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 168595820.538354844 of field Shape_Area of feature 9376 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 3147385125.82944155 of field Shape_Area of feature 9458 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 547638252.802138448 of field Shape_Area of feature 9469 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 163007417.031543732 of field Shape_Area of feature 10745 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 133633386.314936727 of field Shape_Area of feature 11149 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 173180804.089426875 of field Shape_Area of feature 13665 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 138636794.60179171 of field Shape_Area of feature 14042 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 283887954.940669477 of field Shape_Area of feature 14337 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 2025576187.14254069 of field Shape_Area of feature 15379 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 120364499.379915103 of field Shape_Area of feature 17814 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 173263646.536143333 of field Shape_Area of feature 21704 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 143106210.372174978 of field Shape_Area of feature 22029 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 121211556.351376593 of field Shape_Area of feature 22299 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 125418829.565116376 of field Shape_Area of feature 22476 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 101642067.646947324 of field Shape_Area of feature 22767 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 277580596.56172204 of field Shape_Area of feature 22776 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 106625233.760301217 of field Shape_Area of feature 22808 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 432888613.277687192 of field Shape_Area of feature 22841 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 190435690.40849191 of field Shape_Area of feature 22862 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 142901117.061412185 of field Shape_Area of feature 22879 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 558062914.781371832 of field Shape_Area of feature 22963 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 480620514.057915211 of field Shape_Area of feature 23040 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 122278866.733956084 of field Shape_Area of feature 23630 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 118810112.146702021 of field Shape_Area of feature 24092 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 384865796.064605355 of field Shape_Area of feature 24124 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 102466561.021018624 of field Shape_Area of feature 24203 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 447779253.355860591 of field Shape_Area of feature 25322 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 123620786.913064286 of field Shape_Area of feature 25376 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 106170538.611210927 of field Shape_Area of feature 25412 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 739096502.608408332 of field Shape_Area of feature 26025 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 258043484.5750857 of field Shape_Area of feature 26153 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 874451290.188724637 of field Shape_Area of feature 28209 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 198082920.387768328 of field Shape_Area of feature 28239 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 194449396.597326189 of field Shape_Area of feature 29669 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 683174232.265883207 of field Shape_Area of feature 30406 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 101974767.635791883 of field Shape_Area of feature 30753 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 223644321.172273815 of field Shape_Area of feature 31499 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 117380469.700505838 of field Shape_Area of feature 32564 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 194562086.288173378 of field Shape_Area of feature 34949 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 101841330.152706802 of field Shape_Area of feature 35669 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 139223685.390730053 of field Shape_Area of feature 39683 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 113238389.242846534 of field Shape_Area of feature 39709 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 922304999.238167763 of field Shape_Area of feature 39727 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 238968605.406685352 of field Shape_Area of feature 39804 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 143278009.124361694 of field Shape_Area of feature 39858 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 137587920.204903603 of field Shape_Area of feature 39901 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 214682665.872249633 of field Shape_Area of feature 39913 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 107308225.825679481 of field Shape_Area of feature 39924 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 115798528.718260601 of field Shape_Area of feature 39945 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 121117565.464299023 of field Shape_Area of feature 39946 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 150095009.903521806 of field Shape_Area of feature 39966 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 101026083.016307905 of field Shape_Area of feature 39979 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 297807990.790300786 of field Shape_Area of feature 40070 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 138490097.688674748 of field Shape_Area of feature 40077 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 152186352.093491733 of field Shape_Area of feature 42536 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 179706212.707511872 of field Shape_Area of feature 42539 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 374392775.922663271 of field Shape_Area of feature 42730 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 149778879.735050768 of field Shape_Area of feature 43221 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 213195290.87049827 of field Shape_Area of feature 43222 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 579701651.279308796 of field Shape_Area of feature 43276 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 214739117.398404419 of field Shape_Area of feature 43338 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 113872803.019302383 of field Shape_Area of feature 43344 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 536279119.382911444 of field Shape_Area of feature 43450 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# ✅ Exported: S:\CAMELS-CH\CAMELS-chem\data\GIS\CORINE_Landuse\U2006_CLC2000_V2020_20u1.shp
# 📂 GDB directory found: S:\CAMELS-CH\CAMELS-chem\data\GIS\CORINE_Landuse\CLC_downloads\175377\Results\U2012_CLC2006_V2020_20u1.gdb
#   📄 Available layers: ['U2012_CLC2006_V2020_20u1']
# C:\Users\mkauzlaric\AppData\Local\Temp\ipykernel_2296\2495070687.py:15: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf.to_file(out_shp)
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Shape_Length' to 'Shape_Leng'
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 105715789.176638395 of field Shape_Area of feature 2052 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 125346629.156778634 of field Shape_Area of feature 3383 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 105957317.114794374 of field Shape_Area of feature 6339 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 433665539.703231752 of field Shape_Area of feature 6373 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 191058882.157537788 of field Shape_Area of feature 6387 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 129094630.427107826 of field Shape_Area of feature 6410 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 372884457.127524495 of field Shape_Area of feature 6437 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 180426848.90126279 of field Shape_Area of feature 7138 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 127005573.159653768 of field Shape_Area of feature 9439 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 149871185.751901835 of field Shape_Area of feature 9531 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 233155444.970243812 of field Shape_Area of feature 10629 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 519643180.007652938 of field Shape_Area of feature 10738 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 213383572.077096313 of field Shape_Area of feature 10764 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 121682052.496774822 of field Shape_Area of feature 11381 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 234661762.491448194 of field Shape_Area of feature 11402 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 156109299.420854181 of field Shape_Area of feature 13620 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 116933354.883792594 of field Shape_Area of feature 13633 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 138657502.85078302 of field Shape_Area of feature 13656 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 156396605.758853793 of field Shape_Area of feature 14528 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 115118806.24086751 of field Shape_Area of feature 15412 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 173643662.649856657 of field Shape_Area of feature 17761 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 148141918.376174331 of field Shape_Area of feature 17970 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 118904497.289794251 of field Shape_Area of feature 18131 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 125851103.316521198 of field Shape_Area of feature 18245 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 102338189.756001785 of field Shape_Area of feature 18478 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 393367234.379401207 of field Shape_Area of feature 20839 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 105487539.0221432 of field Shape_Area of feature 26336 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 104869672.407712862 of field Shape_Area of feature 26340 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 167530924.080357373 of field Shape_Area of feature 26390 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 108459400.518446386 of field Shape_Area of feature 26409 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 146912031.105327457 of field Shape_Area of feature 26454 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 168222178.469844073 of field Shape_Area of feature 26482 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 109073854.488583669 of field Shape_Area of feature 26525 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 521146970.804219842 of field Shape_Area of feature 26605 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 207214387.336569816 of field Shape_Area of feature 26632 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 168433996.630891651 of field Shape_Area of feature 27723 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 541994024.115290403 of field Shape_Area of feature 27804 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 302694403.449178219 of field Shape_Area of feature 27827 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 158865174.642213434 of field Shape_Area of feature 27829 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 128241189.92111823 of field Shape_Area of feature 31202 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 121508095.923550189 of field Shape_Area of feature 33334 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 100329249.145904899 of field Shape_Area of feature 33499 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 110843883.344765708 of field Shape_Area of feature 36874 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 101974753.44219926 of field Shape_Area of feature 37697 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 152892111.640041232 of field Shape_Area of feature 40077 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 113872801.782798484 of field Shape_Area of feature 41172 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 535086742.565399826 of field Shape_Area of feature 41231 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 864908812.8611058 of field Shape_Area of feature 41273 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 100700951.212386817 of field Shape_Area of feature 42995 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 364796856.276144385 of field Shape_Area of feature 43115 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 2009944990.96372032 of field Shape_Area of feature 43144 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 145093863.567854226 of field Shape_Area of feature 43213 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 100589911.749644533 of field Shape_Area of feature 43235 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 580250596.731846213 of field Shape_Area of feature 43398 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 237629435.668710589 of field Shape_Area of feature 43570 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 121548618.697787628 of field Shape_Area of feature 43624 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 107826894.033355579 of field Shape_Area of feature 43627 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 137248565.961228639 of field Shape_Area of feature 43628 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 131733942.57666257 of field Shape_Area of feature 43797 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 197494479.522200584 of field Shape_Area of feature 43820 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 214739093.10499537 of field Shape_Area of feature 43833 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 764003162.858246922 of field Shape_Area of feature 43835 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# ✅ Exported: S:\CAMELS-CH\CAMELS-chem\data\GIS\CORINE_Landuse\U2012_CLC2006_V2020_20u1.shp
# 📂 GDB directory found: S:\CAMELS-CH\CAMELS-chem\data\GIS\CORINE_Landuse\CLC_downloads\175386\Results\U2018_CLC2012_V2020_20u1.gdb
#   📄 Available layers: ['U2018_CLC2012_V2020_20u1']
# C:\Users\mkauzlaric\AppData\Local\Temp\ipykernel_2296\2495070687.py:15: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf.to_file(out_shp)
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Shape_Length' to 'Shape_Leng'
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 109740645.53112632 of field Shape_Area of feature 4811 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 118313901.831236184 of field Shape_Area of feature 4812 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 394018534.802261472 of field Shape_Area of feature 6810 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 866591425.104014039 of field Shape_Area of feature 6892 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 155553284.551193446 of field Shape_Area of feature 8109 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 118307899.477243125 of field Shape_Area of feature 8514 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 132234274.805114061 of field Shape_Area of feature 9291 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 174124907.707404226 of field Shape_Area of feature 12401 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 149983081.979649782 of field Shape_Area of feature 12702 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 119495078.053452045 of field Shape_Area of feature 12962 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 126794624.019893706 of field Shape_Area of feature 13132 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 342294459.443236768 of field Shape_Area of feature 13419 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 122105151.374211356 of field Shape_Area of feature 13498 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 228935220.518562883 of field Shape_Area of feature 14241 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 214743291.975855678 of field Shape_Area of feature 16753 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 405216324.429918945 of field Shape_Area of feature 20390 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 127204045.414367005 of field Shape_Area of feature 20424 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 180280662.843808383 of field Shape_Area of feature 20453 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 448337698.55864048 of field Shape_Area of feature 20464 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 163191131.984738201 of field Shape_Area of feature 20481 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 137353955.020096809 of field Shape_Area of feature 20499 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 728930120.522077203 of field Shape_Area of feature 20509 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 320105921.163610995 of field Shape_Area of feature 20517 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 219931282.20453608 of field Shape_Area of feature 20532 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 102483493.020056307 of field Shape_Area of feature 20630 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 114767143.856116474 of field Shape_Area of feature 21012 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 124882725.949524939 of field Shape_Area of feature 24064 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 194044733.992200971 of field Shape_Area of feature 24076 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 141992613.623421848 of field Shape_Area of feature 24701 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 213361790.186794966 of field Shape_Area of feature 24832 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 155669223.590450197 of field Shape_Area of feature 24835 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 160575771.937320054 of field Shape_Area of feature 27222 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 217772858.070498079 of field Shape_Area of feature 27266 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 112037045.754542947 of field Shape_Area of feature 27362 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 137658213.876627892 of field Shape_Area of feature 27642 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 160407135.904471606 of field Shape_Area of feature 27753 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 238400986.919118017 of field Shape_Area of feature 27814 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 157400781.228083223 of field Shape_Area of feature 29189 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 112591835.14572686 of field Shape_Area of feature 29278 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 263612926.96939826 of field Shape_Area of feature 31446 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 103188763.902523309 of field Shape_Area of feature 31803 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# ...
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 117959482.453292847 of field Shape_Area of feature 8521 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 132234274.805114061 of field Shape_Area of feature 9300 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 174071726.226005107 of field Shape_Area of feature 12412 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 150182056.764805406 of field Shape_Area of feature 12712 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 117170658.345748976 of field Shape_Area of feature 12972 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 126420356.368844301 of field Shape_Area of feature 13142 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 342253845.61983639 of field Shape_Area of feature 13429 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 136499321.439264596 of field Shape_Area of feature 13515 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 230081218.505059719 of field Shape_Area of feature 14245 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 214743291.975855678 of field Shape_Area of feature 16759 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 405216324.429918945 of field Shape_Area of feature 20397 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 127204045.414367005 of field Shape_Area of feature 20431 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 180280662.843808383 of field Shape_Area of feature 20460 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 448337698.55864048 of field Shape_Area of feature 20471 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 163191133.061088294 of field Shape_Area of feature 20488 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 137605566.66709742 of field Shape_Area of feature 20506 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 728930121.708328366 of field Shape_Area of feature 20516 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 320196664.426411808 of field Shape_Area of feature 20524 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 219931282.20453608 of field Shape_Area of feature 20539 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 102483493.020056307 of field Shape_Area of feature 20637 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 114767144.089966595 of field Shape_Area of feature 21019 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 122801291.447872326 of field Shape_Area of feature 24069 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 194822708.677500933 of field Shape_Area of feature 24081 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 139313315.089966506 of field Shape_Area of feature 24710 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 213361790.186794966 of field Shape_Area of feature 24845 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 155669223.590450197 of field Shape_Area of feature 24848 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 160405277.441069335 of field Shape_Area of feature 27248 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 217864519.390545934 of field Shape_Area of feature 27291 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 112201329.317443654 of field Shape_Area of feature 27387 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 137369192.388928115 of field Shape_Area of feature 27667 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 160407135.904471606 of field Shape_Area of feature 27779 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 238505886.442166716 of field Shape_Area of feature 27843 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 157400781.228083223 of field Shape_Area of feature 29211 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 112591835.14572686 of field Shape_Area of feature 29300 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 263612926.96939826 of field Shape_Area of feature 31470 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 103188763.902523309 of field Shape_Area of feature 31827 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 212621896.651015908 of field Shape_Area of feature 36788 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 312678681.609208763 of field Shape_Area of feature 37755 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 113807932.946405217 of field Shape_Area of feature 37970 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 117432513.391954884 of field Shape_Area of feature 42959 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 234749455.782812297 of field Shape_Area of feature 46669 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 2090354804.06533599 of field Shape_Area of feature 46718 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# ✅ Exported: S:\CAMELS-CH\CAMELS-chem\data\GIS\CORINE_Landuse\U2018_CLC2018_V2020_20u1.shp
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 134513775.369786382 of field Shape_Area of feature 46755 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 715209332.318564773 of field Shape_Area of feature 46801 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 101300985.341130927 of field Shape_Area of feature 46856 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 151666530.072769314 of field Shape_Area of feature 46888 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 473518151.366814017 of field Shape_Area of feature 46912 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 612218115.468405962 of field Shape_Area of feature 47120 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 580272497.311923146 of field Shape_Area of feature 47148 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 122390474.382304713 of field Shape_Area of feature 47181 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 159965801.60500437 of field Shape_Area of feature 47202 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 536490597.485569477 of field Shape_Area of feature 47207 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 108897198.682553321 of field Shape_Area of feature 47403 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 120966951.478780761 of field Shape_Area of feature 47404 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 265867332.574108422 of field Shape_Area of feature 47481 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 131162289.403748184 of field Shape_Area of feature 47485 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 108507666.81081298 of field Shape_Area of feature 47527 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# p:\Hydrologie\AnacondaMartina\envs\env_CAMELS_CH-chem\Lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value 108794356.286462039 of field Shape_Area of feature 47528 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(

# %% [markdown]
# * #### The users should NOT change anything in the code below here.

# %% [markdown]
# # Import data
# * Load catchments and look at full table
#
# *Note: Run the next two lines only if you downloaded the CORINE data manually (and didn't load yet the catchments shape file)*

# %%
catchments = gpd.read_file(catchments_shp)
catchments_3035 = catchments.to_crs("EPSG:3035")

# %%
catchments["bafu_id"] = catchments["gauge_id"]
catchments
# Out:
#      gauge_id  sensor_id  nawaf_id  nawat_id isot_id  chirp_id  \
# 0        2009     2009.0    1837.0    1837.0   NIO04       NaN
# 1        2011     2011.0       NaN    4070.0    None       NaN
# 2        2016     2016.0    1833.0    1833.0   NIO02       NaN
# 3        2018     2018.0    1835.0    1339.0    None       NaN
# 4        2019     2019.0       NaN    1852.0   NIO01       NaN
# ..        ...        ...       ...       ...     ...       ...
# 110      2617     2617.0       NaN       NaN    None       NaN
# 111      2623     2623.0       NaN       NaN    None       NaN
# 112      2634     2634.0    6169.0    1181.0    None       NaN
# 113      2635     2635.0       NaN       NaN    None       NaN
# 114      2640        NaN       NaN    1504.0    None       NaN
#
#                   gauge_name   water_body  gauge_east  gauge_nort  gauge_lon  \
# 0              Porte du Scex        Rhône      557660      133280       6.89
# 1                       Sion        Rhône      593770      118630       7.36
# 2                      Brugg         Aare      657000      259360       8.19
# 3                  Mellingen        Reuss      662830      252580       8.27
# 4                Brienzwiler         Aare      649930      177380       8.09
# ..                       ...          ...         ...         ...        ...
# 110                  Müstair          Rom      830800      168700      10.45
# 111                 Oberwald        Rhone      669900      154075       8.35
# 112                    Emmen  Kleine Emme      663700      213630       8.28
# 113        Einsiedeln, Gross    Grossbach      700710      218125       8.77
# 114  Delémont, Pré-Guillaume        Sorne      593380      245940       7.35
#
#      gauge_lat     area  area_swiss  \
# 0        46.35   5239.4   99.994914
# 1        46.22   3372.4  100.000000
# 2        47.48  11681.3  100.000000
# 3        47.42   3385.8  100.000000
# 4        46.75    555.2  100.000000
# ..         ...      ...         ...
# 110      46.63    128.6   42.552175
# 111      46.53     93.3  100.000000
# 112      47.07    478.3  100.000000
# 113      47.11      8.9  100.000000
# 114      47.36    213.9  100.000000
#
#                                               geometry  bafu_id
# 0    POLYGON Z ((2674253.038 1167429.881 0, 2674340...     2009
# 1    POLYGON Z ((2674253.038 1167429.881 0, 2674340...     2011
# 2    POLYGON Z ((2655969.68 1259695.589 0, 2655976....     2016
# 3    POLYGON Z ((2663723.38 1252919.068 0, 2663794....     2018
# 4    POLYGON Z ((2669196.412 1183579.51 0, 2669203....     2019
# ..                                                 ...      ...
# 110  POLYGON Z ((2820942.826 1171469.984 0, 2820953...     2617
# 111  POLYGON Z ((2674253.038 1167429.881 0, 2674340...     2623
# 112  POLYGON Z ((2653429.237 1216261.807 0, 2653439...     2634
# 113  POLYGON Z ((2701144.527 1218073.633 0, 2701261...     2635
# 114  POLYGON Z ((2584725.396 1248420.902 0, 2584728...     2640
#
# [115 rows x 16 columns]

# %% [markdown]
# Now we extract landcover attributes as area percentages as we did for CAMELS-CH (see also https://github.com/camels-ch/camels-ch/blob/main/landcover_attributes/corine_landcover_CH.R)

# %%
# Prepare the dictionary of CORINE data shapefiles in GIS_dir
import re

clc_by_year = {}

# Loop through files and extract year
for filename in os.listdir(GIS_dir):
    if filename.endswith(".shp"):
        # Try to find the year using regex
        match = re.search(r'CLC(20\d\d)', filename)
        if match:
            year = match.group(1)
            # Remove the .shp extension
            name = os.path.splitext(filename)[0]
            clc_by_year[year] = name

print("📁 Detected CORINE files by year:")
print(clc_by_year)
# Out:
# 📁 Detected CORINE files by year:
# {'2000': 'U2006_CLC2000_V2020_20u1', '2006': 'U2012_CLC2006_V2020_20u1', '2012': 'U2018_CLC2012_V2020_20u1', '2018': 'U2018_CLC2018_V2020_20u1'}

# %% [markdown]
# Now we define helper functions we nned to extract and reclassify the data

# %%
# --- Helper Functions ---

def reclass_clc(clc, code_column=None):
    """Reclassify CORINE land cover codes into CAMELS-CH land use categories."""
    reclass_dict = {
        111: "urban_perc", 112: "urban_perc", 121: "urban_perc", 122: "urban_perc", 123: "urban_perc", 124: "urban_perc",
        131: "loose_rock_perc", 132: "loose_rock_perc", 133: "loose_rock_perc",
        141: "grass_perc", 142: "urban_perc",
        211: "crop_perc", 212: "crop_perc", 213: "crop_perc",
        221: "scrub_perc", 222: "scrub_perc", 223: "scrub_perc",
        231: "grass_perc",
        241: "crop_perc", 242: "crop_perc", 243: "crop_perc", 244: "scrub_perc",
        311: "dwood_perc", 312: "ewood_perc", 313: "mixed_wood_perc",
        321: "grass_perc", 322: "wetlands_perc", 323: "scrub_perc", 324: "scrub_perc",
        331: "loose_rock_perc", 332: "rock_perc", 333: "loose_rock_perc", 334: "loose_rock_perc", 335: "ice_perc",
        411: "wetlands_perc", 412: "wetlands_perc", 421: "wetlands_perc", 422: "wetlands_perc", 423: "wetlands_perc",
        511: "inwater_perc", 512: "inwater_perc", 521: "inwater_perc", 522: "inwater_perc", 523: "inwater_perc",
        999: "blank_perc", 990: "blank_perc", 995: "inwater_perc"
    }
    # Convert string codes to integers for mapping
    clc["reclass"] = clc[code_column].astype(int).map(reclass_dict).fillna("na")
    return clc

def clip_clc_to_catchments(catchments, clc, code_col="reclass", id_col="gauge_id"):
    """Clip land cover data to catchments and aggregate area per reclassified class."""
    df_all = pd.DataFrame()

    for i in tqdm.tqdm(range(len(catchments)), desc="Processing catchments"):
        catch_i = catchments.iloc[[i]]
        catch_id = catch_i[id_col].values[0]

        try:
            clc_i = gpd.overlay(clc, catch_i, how="intersection")
        except Exception:
            continue

        if clc_i.empty:
            continue

        clc_i["area"] = clc_i.geometry.area
        clc_agg = clc_i.groupby(code_col)["area"].sum().reset_index()
        clc_agg.columns = [code_col, catch_id]

        if df_all.empty:
            df_all = clc_agg
        else:
            df_all = pd.merge(df_all, clc_agg, on=code_col, how="outer")

    return df_all

def calculate_percentage_table(area_df, catchments):
    """Convert area table to percentage based on catchment area."""
    area_df = area_df.set_index("reclass")
    area_df = area_df.fillna(0)
    catchment_areas = pd.Series(catchments.geometry.area.values, index=catchments["gauge_id"].values)
    percentage_df = area_df.copy()
    for col in area_df.columns:
        percentage_df[col] = 100 * area_df[col] / catchment_areas[col]
    return percentage_df

def determine_dominant_class(percentage_df):
    """Create static attribute table with dominant land cover class per catchment."""
    dominant_class = percentage_df.idxmax()
    static_df = percentage_df.T.copy()
    static_df["dom_land_cover"] = dominant_class
    return static_df

# %%
# --- Main Processing ---
#Preallocate table for static attributes
all_static_tables = {}

for year, filename in clc_by_year.items():
    print(f"\n🌍 Processing year {year}...")

    # Load and reclassify
    clc_fp = os.path.join(GIS_dir, f"{filename}.shp")
    clc = gpd.read_file(clc_fp)
    #clc = clc.to_crs("EPSG:3035")
    # Automatically detect code column
    code_col = next((col for col in clc.columns if col.lower().startswith("code_")), "Code")
    # Reclassify based on correct column
    clc = reclass_clc(clc, code_column=code_col)

    # Clip and aggregate
    clipped_area_df = clip_clc_to_catchments(catchments_3035, clc)
    percent_df = calculate_percentage_table(clipped_area_df, catchments_3035)

    # Save percentage table
    percent_df.index.name = "gauge_id"
    percent_df.T.to_csv(f"clc_{year}_perc.csv", sep=";", float_format="%.2f")

    # Static table
    static_df = determine_dominant_class(percent_df)
    all_static_tables[year] = static_df

# Save final static attribute table from 2000
final_static = all_static_tables["2000"]
final_static.index.name = "gauge_id"
final_static = final_static.reset_index()

# Reorder columns to match R output (if needed)
columns_order = ['gauge_id', 'urban_perc', 'loose_rock_perc', 'grass_perc', 'crop_perc',
                 'scrub_perc', 'dwood_perc', 'ewood_perc', 'mixed_wood_perc', 'wetlands_perc',
                 'rock_perc', 'ice_perc', 'inwater_perc', 'blank_perc', 'dom_land_cover']
final_static = final_static[[col for col in columns_order if col in final_static.columns]]

# Save
final_static.to_csv("CAMELS_CH_landcover_attributes.csv", sep=";", float_format="%.2f", index=False)
# Out:
# 🌍 Processing year 2000...
# Processing catchments: 100%|██████████| 115/115 [21:03<00:00, 10.98s/it]
# 🌍 Processing year 2006...
# Processing catchments: 100%|██████████| 115/115 [17:55<00:00,  9.36s/it]
# 🌍 Processing year 2012...
# Processing catchments: 100%|██████████| 115/115 [17:42<00:00,  9.24s/it]
# 🌍 Processing year 2018...
# Processing catchments: 100%|██████████| 115/115 [17:57<00:00,  9.37s/it]

# %% [markdown]
# Now we have our 6-yearly landcover for all catchments together with a static landcover, with 2000 as reference year (which is more or less in the middle, if we consider the full range of data spans between 1980 and 2021).
#
# Finally, we interpolate linearly between the available years and also generate a file per catchment (similarly to what we did for CAMELS-CH, refer to https://github.com/camels-ch/camels-ch/blob/main/landcover_attributes/annual_timeserie_CH.R).

# %%
# Create a new directory for the interpolated time series
interpolated_dir = os.path.join(PATH_OUTPUT, "annual_timeseries")
os.makedirs(interpolated_dir, exist_ok=True)

# Automatically detect available years based on filenames
clc_files = [f for f in os.listdir(PATH_OUTPUT) if f.startswith("clc_") and f.endswith("_perc.csv")]
clc_years = sorted([int(f.split("_")[1]) for f in clc_files])

# Load all available CLC data and store by year
clc_data_by_year = {}
for year in clc_years:
    df = pd.read_csv(f"clc_{year}_perc.csv", sep=";", index_col=0)
    clc_data_by_year[year] = df

# %%
# Generate a full range of years from the available years
full_years = list(range(clc_years[0], clc_years[-1] + 1))       

# Get all catchments and land cover classes
all_catchments = clc_data_by_year[2000].index.tolist()
landcover_classes = clc_data_by_year[2000].columns.tolist()

# Preallocate final dataframe: MultiIndex with (gauge_id, year)
index = pd.MultiIndex.from_product([all_catchments, full_years], names=["gauge_id", "year"])
# Uncomment the following line if you don't want to generate a file with annual timeseries for all catchments)
landcover_timeseries = pd.DataFrame(index=index, columns=landcover_classes)

# %%
# Interpolate for each catchment
for gauge in tqdm.tqdm(all_catchments, desc="Interpolating time series"):
    catchment_ts = pd.DataFrame(index=clc_years, columns=landcover_classes, dtype=float)
    catchment_ts.index = catchment_ts.index.astype(int)
    catchment_ts = catchment_ts.reindex(full_years)

    for year in clc_years:
        catchment_ts.loc[year] = clc_data_by_year[year].loc[gauge].astype(float)

    # Interpolate
    catchment_ts_interp = catchment_ts.astype(float).interpolate(method="linear", axis=0).reindex(full_years)

    # Align columns before assignment
    catchment_ts_interp = catchment_ts_interp[catchment_ts.columns]

    # Store (uncomment the following two lines if you don't want to generate a file with annual timeseries for all catchments)
    for year in full_years:
        landcover_timeseries.loc[(gauge, year), :] = catchment_ts_interp.loc[year]
    
    # Save individual CSV for each catchment
    catchment_ts_interp.index.name = "year"
    catchment_ts_interp.to_csv(os.path.join(interpolated_dir, f"CAMELS_CH_Chem_landcover_{gauge}_annual_timeseries.csv"), sep=";", float_format="%.2f")
# Out:
# Interpolating time series: 100%|██████████| 115/115 [00:01<00:00, 96.40it/s]

# %% [markdown]
# Run the next lines of code if you want to generate a file with annual timeseries for all catchments, otherwise yu are done, yay!

# %%
# Reset index and save to file
landcover_timeseries = landcover_timeseries.reset_index()
output_filename = f"CAMELS_CH_Chem_landcover_annual_timeseries_{clc_years[0]}_{clc_years[-1]}.csv"
landcover_timeseries.to_csv(output_filename, sep=";", float_format="%.2f", index=False)

# %% [markdown]
# Adjust the name of the files

# %%
folder_2020 = "../results/landcover/annual_timeseries"
output_folder = "../results/Dataset/catchment_aggregated_data/landcover_data"
os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(folder_2020):
    if filename.startswith("CAMELS_CH_Chem_landcover_") and filename.endswith("_annual_timeseries.csv"):
        
        # Extract basin code
        parts = filename.split("_")
        basin_code = parts[4]

        # Load file
        input_path = os.path.join(folder_2020, filename)
        df = pd.read_csv(input_path, sep=";")
        df.columns = ['date', 'crop_perc', 'dwood_perc', 'ewood_perc', 'grass_perc',
       'ice_perc', 'inwater_perc', 'loose_rock_perc', 'mixed_wood_perc',
       'rock_perc', 'scrub_perc', 'urban_perc', 'wetlands_perc'] 
        # Repeat the last row (assumed to be 2018) for 2019 and 2020
        if not df.empty:
            last_row = df.iloc[-1].copy()

            for year in [2019, 2020]:
                new_row = last_row.copy()
                new_row[df.columns[0]] = year  # Assumes first column is 'year'
                df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)

        # Create new filename
        new_filename = f"camels_ch_chem_landcover_{basin_code}.csv"
        output_path = os.path.join(output_folder, new_filename)

        # Save
        df.to_csv(output_path, index=False)

# %% [markdown]
# # End
